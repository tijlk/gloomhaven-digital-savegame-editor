# %%
import sys
import struct
import datetime
import json
import argparse
import base64
import urllib

theClass = {}
verbose = False

def nothing(value):
    return value

def date(s, options):
    d = popp(s, options[0])
    return d.encode("hex")

def unpack_value(s, options):
    return struct.unpack(options[1], popp(s, options[0]))[0]

def printverbose(string):
    global verbose
    if verbose:
        print(string)

def LengthPrefixedString(s, options=""):
    Length = 0
    shift = 0
    c = True
    while c:
        byte = struct.unpack('<B', popp(s, 1))[0]
        if byte&128:
            byte^=128
        else:
            c = False
        Length += byte<<shift
        shift+=7
    return popp(s, Length)


PrimitiveTypeEnumeration = {
    1:[b'Boolean',unpack_value, [1, '<B']],
    2:[b'Byte', unpack_value, [1, '<b']],
    3:[b'Char', unpack_value, [1, '<b']],
    5:[b'Decimal', LengthPrefixedString, 0],
    6:[b'Double', unpack_value, [8, '<Q']],
    7:[b'Int16', unpack_value, [2, '<h']],
    8:[b'Int32', unpack_value, [4, '<i']],
    9:[b'Int64', unpack_value, [8, '<q']],
    10:[b'SByte', unpack_value, [1, '<B']],
    11:[b'Single', unpack_value, [4, '<I']],
    12:[b'TimeSpan', date, [8, '<Q']],
    13:[b'DateTime', date, [8, '<Q']],
    14:[b'UInt16', unpack_value, [2, '<H']],
    15:[b'UInt32', unpack_value, [4, '<I']],
    16:[b'UInt64', unpack_value, [8, '<Q']],
    17:[b'Null', unpack_value, [1, '<B']],
    18:[b'String', LengthPrefixedString, 0]
}

def parse_value(object, s):
    if object[0]==b"Primitive":
        for p in PrimitiveTypeEnumeration:
            if PrimitiveTypeEnumeration[p][0] == object[1]:
                value = PrimitiveTypeEnumeration[p][1](s, PrimitiveTypeEnumeration[p][2])
        try:
            printverbose(object[1]+b' : '+bytes(value))
        except TypeError:
            print("object[1]", type(object[1]))
            print("bytes(value)", type(bytes(value)))
            raise Exception
    else:
        value = parse_object(s)
    return value

def parse_values(objectID, s):
    values = []
    myClass = theClass[objectID]
    a = 0
    for object in myClass[0]:
        printverbose(myClass[1][a]+b' : '+object[0])
        values.append((myClass[1][a]+b' : '+object[0], parse_value(object, s)))
        a+=1
    return values

BinaryArrayTypeEnumeration = {
    0:[b'Single'],
    1:[b'Jagged'],
    2:[b'Rectangular'],
    3:[b'SingleOffset'],
    4:[b'JaggedOffset'],
    5:[b'RectangularOffset']
}

def Primitive(s):
    return PrimitiveTypeEnumeration[struct.unpack('<B', popp(s, 1))[0]]

def SystemClass(s):
    return LengthPrefixedString(s)

def none(s):
    pass

def ClassTypeInfo(s):
    classTypeInfo = {}
    TypeName = LengthPrefixedString(s)
    LibraryId = struct.unpack('<I', popp(s, 4))[0]
    classTypeInfo[b'TypeName'] = TypeName
    classTypeInfo[b'LibraryId'] = LibraryId
    return classTypeInfo


BinaryTypeEnumeration = {
    0:[b'Primitive', Primitive],
    1:[b'String', none],
    2:[b'Object', none],
    3:[b'SystemClass', SystemClass],
    4:[b'Class', ClassTypeInfo],
    5:[b'ObjectArray', none],
    6:[b'StringArray', none],
    7:[b'PrimitiveArray', Primitive]
}


def SerializedStreamHeader(s):
    serializedStreamHeader = {}
    (RootId, HeaderId, MajorVersion, MinorVersion) = struct.unpack('<IIII', popp(s, 16))
    serializedStreamHeader['RootId'] = RootId
    serializedStreamHeader['HeaderId'] = HeaderId
    serializedStreamHeader['MajorVersion'] = MajorVersion
    serializedStreamHeader['MinorVersion'] = MinorVersion
    printverbose('\tRootId : 0x%x'%RootId)
    printverbose('\tHeaderId : 0x%x'%HeaderId)
    printverbose('\tMajorVersion : 0x%x'%MajorVersion)
    printverbose('\tMinorVersion : 0x%x'%MinorVersion)
    return serializedStreamHeader

def BinaryLibrary(s):
    binaryLibrary = {}
    LibraryId = struct.unpack('<I', popp(s, 4))[0]
    LibraryName = LengthPrefixedString(s)
    binaryLibrary['LibraryId'] = LibraryId
    binaryLibrary['LibraryName'] = LibraryName
    printverbose('\tLibraryId : 0x%x'%LibraryId)
    printverbose('\tLibraryName : %s'%LibraryName)
    return binaryLibrary

def ClassInfo(s):
    classInfo = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    Name = LengthPrefixedString(s)
    MemberCount = struct.unpack('<I', popp(s, 4))[0]
    MemberNames = []
    for i in range(MemberCount):
        MemberNames.append(LengthPrefixedString(s))
    printverbose('\t\tObjectId : 0x%x'%ObjectId)
    printverbose('\t\tName : %s'%Name)
    printverbose('\t\tMemberCount : %d'%MemberCount)
    printverbose('\t\tMemberNames : %s'%MemberNames)
    classInfo['ObjectId'] = ObjectId
    classInfo['Name'] = Name
    classInfo['MemberCount'] = MemberCount
    classInfo['MemberNames'] = MemberNames
    return classInfo

def MemberTypeInfo(s, c):
    memberTypeInfo = {}
    BinaryTypeEnums = []
    binaryTypeEnums = []
    AdditionalInfos = []
    for i in range(c):
        binaryTypeEnum = BinaryTypeEnumeration[struct.unpack('<B', popp(s, 1))[0]]
        binaryTypeEnums.append(binaryTypeEnum)
        BinaryTypeEnums.append(binaryTypeEnum[0])
    for i in binaryTypeEnums:
        if i[0] == b'Primitive' or i[0] == b'PrimitiveArray':
            AdditionalInfos.append((i[0],i[1](s)[0]))
        else:
            AdditionalInfos.append((i[0],i[1](s)))
    printverbose('\t\tBinaryTypeEnums : %s'%BinaryTypeEnums)
    printverbose('\t\tAdditionalInfos : %s'%AdditionalInfos)
    memberTypeInfo['BinaryTypeEnums'] = BinaryTypeEnums
    memberTypeInfo['AdditionalInfos'] = AdditionalInfos
    return memberTypeInfo

def ClassWithMembersAndTypes(s):
    classWithMembersAndTypes = {}
    printverbose('\tClassInfo')
    Members = ClassInfo(s)
    MemberCount = Members['MemberCount']
    printverbose('\tMemberTypeInfo')
    MemberTypeI = MemberTypeInfo(s, MemberCount)
    LibraryId = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tLibraryId : 0x%x'%LibraryId)
    theClass[Members['ObjectId']] = (MemberTypeI['AdditionalInfos'], Members['MemberNames'])
    classWithMembersAndTypes['ClassInfo'] = Members
    classWithMembersAndTypes['MemberTypeInfo'] = MemberTypeI
    classWithMembersAndTypes['LibraryId'] = LibraryId
    classWithMembersAndTypes['Values'] = parse_values(Members['ObjectId'], s)
    return classWithMembersAndTypes

def BinaryObjectString(s):
    binaryObjectString = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    Value = LengthPrefixedString(s)
    printverbose('\tObjectId : 0x%x'%ObjectId)
    printverbose('\tValue : %s'%Value)
    binaryObjectString['ObjectId'] = ObjectId
    binaryObjectString['Value'] = Value
    return binaryObjectString

def ClassWithId(s):
    classWithId = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    MetadataId = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tObjectId : 0x%x'%ObjectId)
    classWithId['ObjectId'] = ObjectId
    classWithId['MetadataId'] = MetadataId
    classWithId['Values'] = parse_values(MetadataId, s)
    return classWithId

def MemberReference(s):
    memberReference = {}
    IdRef = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tIdRef : 0x%x'%IdRef)
    memberReference['IdRef'] = IdRef
    return memberReference

def SystemClassWithMembersAndTypes(s):
    systemClassWithMembersAndTypes = {}
    printverbose('\tClassInfo')
    Members = ClassInfo(s)
    MemberCount = Members['MemberCount']
    printverbose('\tMemberTypeInfo')
    MemberTypeI = MemberTypeInfo(s, MemberCount)
    theClass[Members['ObjectId']] = (MemberTypeI['AdditionalInfos'], Members['MemberNames'])
    systemClassWithMembersAndTypes['ClassInfo'] = Members
    systemClassWithMembersAndTypes['MemberTypeInfo'] = MemberTypeI
    systemClassWithMembersAndTypes['Values'] = parse_values(Members['ObjectId'], s)
    return systemClassWithMembersAndTypes


def BinaryArray(s):
    binaryArray = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    BinaryArrayTypeEnum = BinaryArrayTypeEnumeration[struct.unpack('<B', popp(s, 1))[0]][0]
    Rank = struct.unpack('<I', popp(s, 4))[0]
    Lengths = []
    LowerBounds = []
    for i in range(Rank):
        Lengths.append(struct.unpack('<I', popp(s, 4))[0])
    if 'Offset' in BinaryArrayTypeEnum:
        for i in range(Rank):
            LowerBounds.append(struct.unpack('<I', popp(s, 4))[0])
        binaryArray['LowerBounds'] = LowerBounds
    TypeEnum = BinaryTypeEnumeration[struct.unpack('<B', popp(s, 1))[0]]
    AdditionalTypeInfo = TypeEnum[1](s)
    printverbose('\tObjectId : 0x%x'%ObjectId)
    printverbose('\tBinaryArrayTypeEnum : %s'%BinaryArrayTypeEnum)
    printverbose('\tRank : %d'%Rank)
    printverbose('\tLengths : %s'%Lengths)
    printverbose('\tLowerBounds : %s'%LowerBounds)
    printverbose('\tTypeEnum : %s'%TypeEnum[0])
    printverbose('\tAdditionalTypeInfo : ')
    printverbose(AdditionalTypeInfo)
    binaryArray['ObjectId'] = ObjectId
    binaryArray['BinaryArrayTypeEnum'] = BinaryArrayTypeEnum
    binaryArray['Rank'] = Rank
    binaryArray['Lengths'] = Lengths
    binaryArray['TypeEnum'] = TypeEnum[0]
    binaryArray['AdditionalTypeInfo'] = AdditionalTypeInfo
    return binaryArray

def ObjectNull(s):
    pass

def ObjectNullMultiple256(s):
    objectNullMultiple256 = {}
    NullCount = struct.unpack('<B', popp(s, 1))[0]
    printverbose('\tNullCount : %d'%NullCount)
    objectNullMultiple256['NullCount'] = NullCount
    return objectNullMultiple256

def ObjectNullMultiple(s):
    objectNullMultiple = {}
    NullCount = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tNullCount : %d'%NullCount)
    objectNullMultiple['NullCount'] = NullCount
    return objectNullMultiple

def ClassWithMembers(s):
    classWithMembers = {}
    printverbose('\tClassInfo')
    Members = ClassInfo(s)
    LibraryId = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tLibraryId : 0x%x'%LibraryId)
    classWithMembers['ClassInfo'] = Members
    classWithMembers['LibraryId'] = LibraryId
    return classWithMembers

def SystemClassWithMembers(s):
    systemClassWithMembers = {}
    printverbose('\tClassInfo')
    Members = ClassInfo(s)
    systemClassWithMembers['ClassInfo'] = Members
    return systemClassWithMembers

def MemberPrimitiveTyped(s):
    memberPrimitiveTyped = {}
    primitive = Primitive(s)
    printverbose('\t'+primitive[0])
    value = primitive[1](s, primitive[2])
    printverbose(value)
    memberPrimitiveTyped['PrimitiveTypeEnum'] = primitive[0]
    memberPrimitiveTyped['Value'] = value
    return memberPrimitiveTyped

def ArraySingleObject(s):
    arraySingleObject = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    Length = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tObjectId : 0x%x'%ObjectId)
    printverbose('\tLength : 0x%x'%Length)
    arraySingleObject['ObjectId'] = ObjectId
    arraySingleObject['Length'] = Length
    arraySingleObject['Values'] = []
    for o in range(Length):
        arraySingleObject['Values'].append(parse_object(s))
    return arraySingleObject

def ArraySinglePrimitive(s):
    arraySinglePrimitive = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    Length = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tObjectId : 0x%x'%ObjectId)
    printverbose('\tLength : 0x%x'%Length)
    primitive = Primitive(s)
    printverbose('\t'+primitive[0])
    arraySinglePrimitive['ObjectId'] = ObjectId
    arraySinglePrimitive['Length'] = Length
    arraySinglePrimitive['PrimitiveTypeEnum'] = primitive[0]
    arraySinglePrimitive['Values'] = []
    if primitive[0] != b'Byte':
        for o in range(Length):
            value = primitive[1](s, primitive[2])
            printverbose(value)
            arraySinglePrimitive['Values'].append(value)
    else:
        buf = ''.join(s)
        f = open('objectID_%d'%ObjectId, 'w')
        f.write(buf[:Length])
        f.close()
        s.__delslice__(0,Length)
        arraySinglePrimitive['Values'] = b'@objectID_%d'%ObjectId
    return arraySinglePrimitive

def ArraySingleString(s):
    arraySingleString = {}
    ObjectId = struct.unpack('<I', popp(s, 4))[0]
    Length = struct.unpack('<I', popp(s, 4))[0]
    printverbose('\tObjectId : 0x%x'%ObjectId)
    printverbose('\tLength : 0x%x'%Length)
    arraySingleString['ObjectId'] = ObjectId
    arraySingleString['Length'] = Length
    arraySingleString['Values'] = []
    for o in range(Length):
        value = parse_object(s)
        arraySingleString['Values'].append(value)
    return arraySingleString

def MethodCall(s):
    methodCall = {}
    MessageEnum = struct.unpack('<I', popp(s, 4))[0]
    MethodName = StringValueWithCode(s)
    TypeName = StringValueWithCode(s)
    methodCall['MessageEnum'] = MessageEnum
    methodCall['MethodName'] = MethodName
    methodCall['TypeName'] = TypeName
    printverbose('\tMessageEnum : 0x%x'%MessageEnum)
    printverbose('\tMethodName : %s'%MethodName)
    printverbose('\tTypeName : %s'%TypeName)

    if MessageEnum & MessageFlagsEnum['NoContext'] == 0:
        CallContext = StringValueWithCode(s)
        printverbose('\tCallContext : %s'%CallContext)
        methodCall['CallContext'] = CallContext

    if MessageEnum & MessageFlagsEnum['NoArgs'] == 0:
        Args = ArrayOfValueWithCode(s)
        printverbose('\tArgs : %s'%Args)
        methodCall['Args'] = Args

    return methodCall

def ArrayOfValueWithCode(s):
    arrayOfValueWithCode = {}
    arrayOfValueWithCode['Length'] = struct.unpack('<I', popp(s, 4))[0]
    arrayOfValueWithCode['ListOfValueWithCode'] = []

    for v in range(arrayOfValueWithCode['Length']):
        value = {}
        PrimitiveEnum = struct.unpack('<B', popp(s, 1))[0]
        value['PrimitiveTypeEnum'] = PrimitiveTypeEnumeration[PrimitiveEnum][0]
        value['Value'] = PrimitiveTypeEnumeration[PrimitiveEnum][1](s, PrimitiveTypeEnumeration[PrimitiveEnum][2])
        arrayOfValueWithCode['ListOfValueWithCode'].append(value)
    return arrayOfValueWithCode


def StringValueWithCode(s):
    struct.unpack('<B', popp(s, 1))[0]
    return LengthPrefixedString(s)

MessageFlagsEnum = {
    b'NoArgs': 0x00000001,
    b'ArgsInline': 0x00000002,
    b'ArgsIsArray': 0x00000004,
    b'ArgsInArray': 0x00000008,
    b'NoContext': 0x00000010,
    b'ContextInline': 0x00000020,
    b'ContextInArray': 0x00000040,
    b'MethodSignatureInArray': 0x00000080,
    b'PropertiesInArray': 0x00000100,
    b'NoReturnValue': 0x00000200,
    b'ReturnValueVoid': 0x00000400,
    b'ReturnValueInline': 0x00000800,
    b'ReturnValueInArray': 0x00001000,
    b'ExceptionInArray': 0x00002000,
    b'GenericMethod': 0x00008000
}

RecordTypeEnum = {
    0:['SerializedStreamHeader', SerializedStreamHeader],
    1:['ClassWithId', ClassWithId],
    2:['SystemClassWithMembers', SystemClassWithMembers],
    3:['ClassWithMembers', ClassWithMembers],
    4:['SystemClassWithMembersAndTypes', SystemClassWithMembersAndTypes],
    5:['ClassWithMembersAndTypes', ClassWithMembersAndTypes],
    6:['BinaryObjectString', BinaryObjectString],
    7:['BinaryArray', BinaryArray],
    8:['MemberPrimitiveTyped', MemberPrimitiveTyped],
    9:['MemberReference', MemberReference],
    10:['ObjectNull', ObjectNull],
    11:['MessageEnd', none],
    12:['BinaryLibrary', BinaryLibrary],
    13:['ObjectNullMultiple256', ObjectNullMultiple256],
    14:['ObjectNullMultiple', ObjectNullMultiple],
    15:['ArraySinglePrimitive', ArraySinglePrimitive],
    16:['ArraySingleObject', ArraySingleObject],
    17:['ArraySingleString', ArraySingleString],
    20:['ArrayOfType', ArraySingleString],
    21:['MethodCall', MethodCall],
    22:['MethodReturn']
}


def popp(s, n):
    a = b''
    for c in range(n):
        a += s.pop(0)
    return a

def parse_object(s):
    RecordType = struct.unpack('<B',popp(s,1))[0]
    print(RecordTypeEnum[RecordType][0])
    return (RecordTypeEnum[RecordType][0], RecordTypeEnum[RecordType][1](s))

def parse_file(infile, outfile, verbose=True, encode=False):
    with open(infile, "rb") as f:
        binary = f.read()
    if encode:
        binary = base64.b64decode(urllib.unquote(binary))
    stream = [struct.pack("<B", c) for c in list(binary)]

    myObject = {}
    z=0
    while len(stream) != 0:
        a = parse_object(stream)
        myObject[z] = a
        z+=1
        if a[0] == 'MessageEnd':
            break

    with open(outfile, 'w') as f:
        f.write(json.dumps(myObject))

# %%
root_dir = "/Users/EQ81TW/Library/Application Support/unity." + \
            "FlamingFowlStudios.Gloomhaven/GloomSaves/Campaign"
campaign = "Campaign_[MOD]TabletopToDigital[MOD]_The_Starbase_Raptors_80287552"
infile = f"{root_dir}/{campaign}/{campaign}.dat"
outfile = f"{root_dir}/{campaign}/{campaign}.json"
verbose=True

# %%
parse_file(infile, outfile, verbose=verbose)
# Out:
# SerializedStreamHeader
# 	RootId : 0x1
# 	HeaderId : 0xffffffff
# 	MajorVersion : 0x1
# 	MinorVersion : 0x0
# BinaryLibrary
# 	LibraryId : 0x2
# 	LibraryName : b'MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null'
# BinaryLibrary
# 	LibraryId : 0x3
# 	LibraryName : b'ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null'
# ClassWithMembersAndTypes
# 	ClassInfo
# 		ObjectId : 0x1
# 		Name : b'MapRuleLibrary.State.CMapState'
# 		MemberCount : 41
# 		MemberNames : [b'DLLMode', b'DLCEnabled', b'MapParty', b'CurrentMapPhase', b'UnlockedChapters', b'TutorialCompleted', b'IntroCompleted', b'DifficultySetting', b'HouseRulesSetting', b'HeadquartersState', b'TempleState', b'VillageStates', b'MapMessageStates', b'VisibilitySphereStates', b'JobQuestStates', b'CurrentJobQuestStates', b'PreviousJobQuestStates', b'IsModded', b'IsInitialised', b'Seed', b'UsedEventNames', b'CanDrawCityEvent', b'StartupRewardGroup', b'StartupTreasureTablesRewardGenerationRNGState', b'QueuedUnlockedQuestIDs', b'QueuedCompletedQuestIDs', b'QueuedQuestCompletionRewards', b'QueuedPlatformAchievementsToUnlock', b'MapRNGState', b'ScenarioStartMessages', b'ScenarioCompleteMessages', b'ScenarioRoomRevealMessages', b'GoldMode', b'EnhancementMode', b'SaveOwner', b'MinRequiredCharacters', b'CurrentSingleScenario', b'm_LastItemNetworkID', b'AlreadyRewardedChestTreasureTableIDs', b'MapFTUECompleted', b'JustCompletedLocationState']
# 	MemberTypeInfo
# 		BinaryTypeEnums : [b'Class', b'Class', b'Class', b'Class', b'SystemClass', b'Primitive', b'Primitive', b'Class', b'Class', b'Class', b'Class', b'SystemClass', b'SystemClass', b'SystemClass', b'SystemClass', b'SystemClass', b'SystemClass', b'Primitive', b'Primitive', b'Primitive', b'SystemClass', b'Primitive', b'Class', b'Class', b'SystemClass', b'SystemClass', b'SystemClass', b'SystemClass', b'Class', b'SystemClass', b'SystemClass', b'SystemClass', b'Class', b'Class', b'Class', b'Primitive', b'Object', b'Primitive', b'SystemClass', b'Primitive', b'Object']
# 		AdditionalInfos : [(b'Class', {b'TypeName': b'ScenarioRuleLibrary.ScenarioManager+EDLLMode', b'LibraryId': 3}), (b'Class', {b'TypeName': b'ScenarioRuleLibrary.DLCRegistry+EDLCKey', b'LibraryId': 3}), (b'Class', {b'TypeName': b'MapRuleLibrary.Party.CMapParty', b'LibraryId': 2}), (b'Class', {b'TypeName': b'MapRuleLibrary.PhaseManager.CMapPhaseInHQ', b'LibraryId': 2}), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.State.CChapter, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'Primitive', b'Boolean'), (b'Primitive', b'Boolean'), (b'Class', {b'TypeName': b'MapRuleLibrary.Adventure.EAdventureDifficulty', b'LibraryId': 2}), (b'Class', {b'TypeName': b'ScenarioRuleLibrary.StateShared+EHouseRulesFlag', b'LibraryId': 3}), (b'Class', {b'TypeName': b'MapRuleLibrary.MapState.CHeadquartersState', b'LibraryId': 2}), (b'Class', {b'TypeName': b'MapRuleLibrary.MapState.CTempleState', b'LibraryId': 2}), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CVillageState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CMapMessageState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CVisibilitySphereState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CJobQuestState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CJobQuestState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CJobQuestState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'Primitive', b'Boolean'), (b'Primitive', b'Boolean'), (b'Primitive', b'Int32'), (b'SystemClass', b'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]'), (b'Primitive', b'Boolean'), (b'Class', {b'TypeName': b'ScenarioRuleLibrary.YML.RewardGroup', b'LibraryId': 3}), (b'Class', {b'TypeName': b'ScenarioRuleLibrary.Extensions+RandomState', b'LibraryId': 3}), (b'SystemClass', b'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.Reward, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]'), (b'Class', {b'TypeName': b'ScenarioRuleLibrary.Extensions+RandomState', b'LibraryId': 3}), (b'SystemClass', b'System.Collections.Generic.Dictionary`2[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089],[ScenarioRuleLibrary.CustomLevels.CLevelMessage, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.Dictionary`2[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089],[ScenarioRuleLibrary.CustomLevels.CLevelMessage, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]'), (b'SystemClass', b'System.Collections.Generic.Dictionary`2[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089],[System.Collections.Generic.List`1[[ScenarioRuleLibrary.CustomLevels.CLevelMessage, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]], mscorl ...
# 	LibraryId : 0x2
# b'DLLMode : Class'
# ClassWithMembersAndTypes
# 	ClassInfo
# 		ObjectId : 0xfffffffc
# 		Name : b'ScenarioRuleLibrary.ScenarioManager+EDLLMode'
# 		MemberCount : 1
# 		MemberNames : [b'value__']
# 	MemberTypeInfo
# 		BinaryTypeEnums : [b'Primitive']
# 		AdditionalInfos : [(b'Primitive', b'Int32')]
# 	LibraryId : 0x3
# b'value__ : Primitive'
# b'Int32 : \x00'
# b'DLCEnabled : Class'
# ClassWithMembersAndTypes
# 	ClassInfo
# 		ObjectId : 0xfffffffb
# 		Name : b'ScenarioRuleLibrary.DLCRegistry+EDLCKey'
# 		MemberCount : 1
# 		MemberNames : [b'value__']
# 	MemberTypeInfo
# 		BinaryTypeEnums : [b'Primitive']
# 		AdditionalInfos : [(b'Primitive', b'Int32')]
# 	LibraryId : 0x3
# b'value__ : Primitive'
# b'Int32 : '
# b'MapParty : Class'
# MemberReference
# 	IdRef : 0x6
# b'CurrentMapPhase : Class'
# MemberReference
# 	IdRef : 0x7
# b'UnlockedChapters : SystemClass'
# MemberReference
# 	IdRef : 0x8
# b'TutorialCompleted : Primitive'
# b'Boolean : \x00'
# b'IntroCompleted : Primitive'
# b'Boolean : \x00'
# b'DifficultySetting : Class'
# ClassWithMembersAndTypes
# 	ClassInfo
# 		ObjectId : 0xfffffff7
# 		Name : b'MapRuleLibrary.Adventure.EAdventureDifficulty'
# 		MemberCount : 1
# 		MemberNames : [b'value__']
# 	MemberTypeInfo
# 		BinaryTypeEnums : [b'Primitive']
# 		AdditionalInfos : [(b'Primitive', b'Int32')]
# 	LibraryId : 0x2
# b'value__ : Primitive'
# b'Int32 : \x00\x00'
# b'HouseRulesSetting : Class'
# ClassWithMembersAndTypes
# 	ClassInfo
# 		ObjectId : 0xfffffff6
# 		Name : b'ScenarioRuleLibrary.StateShared+EHouseRulesFlag'
# 		MemberCount : 1
# 		MemberNames : [b'value__']
# 	MemberTypeInfo
# 		BinaryTypeEnums : [b'Primitive']
# 		AdditionalInfos : [(b'Primitive', b'Int32')]
# 	LibraryId : 0x3
# b'value__ : Primitive'
# b'Int32 : \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# b'HeadquartersState : Class'
# MemberReference
# 	IdRef : 0xb
# b'TempleState : Class'
# MemberReference
# 	IdRef : 0xc
# b'VillageStates : SystemClass'
# MemberReference
# 	IdRef : 0xd
# b'MapMessageStates : SystemClass'
# MemberReference
# 	IdRef : 0xe
# b'VisibilitySphereStates : SystemClass'
# MemberReference
# 	IdRef : 0xf
# b'JobQuestStates : SystemClass'
# MemberReference
# 	IdRef : 0x10
# b'CurrentJobQuestStates : SystemClass'
# MemberReference
# 	IdRef : 0x11
# b'PreviousJobQuestStates : SystemClass'
# MemberReference
# 	IdRef : 0x12
# b'IsModded : Primitive'
# b'Boolean : \x00'
# b'IsInitialised : Primitive'
# b'Boolean : \x00'
# b'Seed : Primitive'

# %%
import json
  
# Opening JSON file
with open("/Users/EQ81TW/Developer/gloomhaven-digital-savegame-editor/NetBinaryFormatterParser/blah.json") as f:
# returns JSON object as 
    # a dictionary
    data = json.load(f)
    
import json
import pprint
results = []

def breadcrumb_finder(json_dict_or_list, value, path):
    if json_dict_or_list == value:
        #print(path)
        path.append(json_dict_or_list)
        #print(path)
        final_path = path.copy()
        print(final_path)
        return final_path
        path.pop()
    elif isinstance(json_dict_or_list, dict):
        for k, v in json_dict_or_list.items():
            path.append(k)
            #print(path, v)
            child = breadcrumb_finder(v, value, path)
            path.pop()
                
    elif isinstance(json_dict_or_list, list):
        lst = json_dict_or_list
        for i in range(len(lst)):
            path.append(i)
            #print(path, lst[i])
            child = breadcrumb_finder(lst[i], value, path)
            path.pop()       

final_path = breadcrumb_finder({"blah": [0, {"value": "Sol Goodman"}]}, 'Sol Goodman', [])
# Out:
# ['blah', 1, 'value', 'Sol Goodman']

# %%
def breadcrumb_finder_idrefs(json_dict_or_list, value, path):
    if isinstance(json_dict_or_list, dict) and "IdRef" in json_dict_or_list:
        path.append({"IdRef": json_dict_or_list["IdRef"]})
        return path.copy()
        path.pop()
    elif isinstance(json_dict_or_list, dict):
        for k, v in json_dict_or_list.items():
            path.append(k)
            child = breadcrumb_finder(v, value, path)
            path.pop()
                
    elif isinstance(json_dict_or_list, list):
        lst = json_dict_or_list
        for i in range(len(lst)):
            path.append(i)
            child = breadcrumb_finder(lst[i], value, path)
            path.pop()

# %%
results = []
breadcrumb_finder_idrefs(output, None, [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [310], line 2
#       1 results = []
# ----> 2 breadcrumb_finder_idrefs(output, None, [])
#
# Cell In [309], line 16, in breadcrumb_finder_idrefs(json_dict_or_list, value, path)
#      14 for i in range(len(lst)):
#      15     path.append(i)
# ---> 16     child = breadcrumb_finder(lst[i], value, path)
#      17     path.pop()
#
# TypeError: breadcrumb_finder() missing 1 required positional argument: 'result'

# %%
def breadcrumb_finder(json_dict_or_list, value, path):
    if json_dict_or_list == value:
        path.append(json_dict_or_list)
        return path.copy()
        path.pop()
    elif isinstance(json_dict_or_list, dict):
        for k, v in json_dict_or_list.items():
            path.append(k)
            child = breadcrumb_finder(v, value, path)
            path.pop()
                
    elif isinstance(json_dict_or_list, list):
        lst = json_dict_or_list
        for i in range(len(lst)):
            path.append(i)
            child = breadcrumb_finder(lst[i], value, path)
            path.pop()       


# all_src = ['Sol Goodman']
# for src in all_src:
#     result = breadcrumb_finder(data, src, [])
#     print(result)

# %%
import netfleece

# %%
root_dir = "/Users/EQ81TW/Library/Application Support/unity." + \
            "FlamingFowlStudios.Gloomhaven/GloomSaves/Campaign"
campaign = "Campaign_[MOD]TabletopToDigital[MOD]_The_Starbase_Raptors_80287552"
datfile = f"{root_dir}/{campaign}/{campaign}.dat"
jsonfile = f"{root_dir}/{campaign}/{campaign}.json"
with open(datfile, 'rb') as infile:
    output = netfleece.parseloop(infile)

# %%
import json
import pprint

def breadcrumb_finder(json_dict_or_list, value, path, result):
    if json_dict_or_list == value:
        path.append(json_dict_or_list)
        result.append(path.copy())
        path.pop()
    elif isinstance(json_dict_or_list, dict):
        for k, v in json_dict_or_list.items():
            path.append(k)
            child = breadcrumb_finder(v, value, path, result)
            path.pop()

    elif isinstance(json_dict_or_list, list):
        lst = json_dict_or_list
        for i in range(len(lst)):
            path.append(i)
            child = breadcrumb_finder(lst[i], value, path, result)
            path.pop()       
                
def get_paths_to_value(data, value):
    results = []
    breadcrumb_finder(data, value, [], results)
    return results

def get_paths_to_key_value(data, key, value):
    results = []
    breadcrumb_finder(data, value, [], results)
    return [r for r in results if r[-2:] == [key, value]]

def get_obj_value(data, objectid):
    path = get_paths_to_key_value(data, "ObjectId", objectid)[0]
    return data[path[0]][path[1]]

# %%
get_paths_to_value(output, "PersonalQuestDeck")
# Out:
# [[0, 5, 'ClassInfo', 'MemberNames', 6, 'PersonalQuestDeck']]

# %%
output[0][5]["Values"][6]["IdRef"]
# Out:
# 38

# %%
get_obj_value(output, 38)
# Out:
# {'ObjectId': 38,
#  'MetadataId': 36,
#  'Values': [{'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 95, 'RecordTypeEnum': 'MemberReference'},
#   {'ObjectId': -96,
#    'MetadataId': -90,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 94)
# Out:
# {'ObjectId': 94,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 1334, 'RecordTypeEnum': 'MemberReference'}, 19, 3842],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 1334)
# Out:
# {'ArrayInfo': {'ObjectId': 1334, 'Length': 25},
#  'Values': [{'ObjectId': 10029,
#    'Value': 'PersonalQuest_Law_Bringer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10030,
#    'Value': 'PERSONALQUEST_Eternal_Wanderer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10031,
#    'Value': 'PERSONALQUEST_Piety_in_All_Things',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10032,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10033,
#    'Value': 'PERSONALQUEST_Implement_of_Light',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10034,
#    'Value': 'PERSONALQUEST_Finding_the_Cure',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10035,
#    'Value': 'PERSONALQUEST_Take_Back_the_Trees',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10036,
#    'Value': 'PERSONALQUEST_Elemental_Samples',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10037,
#    'Value': 'PERSONALQUEST_Trophy_Hunt',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10038,
#    'Value': 'PERSONALQUEST_Seeker_of_Xorn',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10039,
#    'Value': 'PERSONALQUEST_The_Thin_Places',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10040,
#    'Value': 'PERSONALQUEST_Foreverquest',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10041,
#    'Value': 'PERSONALQUEST_Zealot_of_the_Blood_God',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10042,
#    'Value': 'PERSONALQUEST_Greed_is_Good',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10043,
#    'Value': 'PERSONALQUEST_Goliath_Toppler',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10044,
#    'Value': 'PERSONALQUEST_Pounds_of_Flesh',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10045,
#    'Value': 'PERSONALQUEST_The_Perfect_Poison',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10046,
#    'Value': 'PERSONALQUEST_Battle_Legend',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10047,
#    'Value': 'PERSONALQUEST_A_Study_of_Anatomy',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 6, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %% [markdown]
# Find PersonalQuestDeck

# %%
struct.pack("<I", 1334)
# Out:
# b'6\x05\x00\x00'

# %%
get_paths_to_value(output, "Sol Goodman")
# Out:
# [[0, 78, 'Values', 0, 'Value', 'Sol Goodman']]

# %%
output[0][78]["Values"][18:20]
# Out:
# [{'IdRef': 1346, 'RecordTypeEnum': 'MemberReference'},
#  {'IdRef': 1347, 'RecordTypeEnum': 'MemberReference'}]

# %%
get_obj_value(output, 1346)
# Out:
# {'ClassInfo': {'ObjectId': 1346,
#   'Name': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'MemberCount': 9,
#   'MemberNames': ['ID',
#    'RewardGenerationRNGState',
#    'RolledRewards',
#    'PersonalQuestConditionState',
#    'IsConcealed',
#    'State',
#    'LastProgressShown',
#    'CurrentPersonalQuestStep',
#    'RewardsByStep']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['String',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Primitive',
#    'SystemClass'],
#   'AdditionalInfos': [None,
#    {'TypeName': 'ScenarioRuleLibrary.Extensions+RandomState', 'LibraryId': 3},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.Party.EPersonalQuestState', 'LibraryId': 2},
#    'Int32',
#    'Int32',
#    'System.Collections.Generic.List`1[[System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.RewardGroup, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]], mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]']},
#  'LibraryId': 2,
#  'Values': [{'ObjectId': 10059,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 10060, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 10061, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ClassInfo': {'ObjectId': -10062,
#     'Name': 'MapRuleLibrary.Party.EPersonalQuestState',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'},
#   5,
#   0,
#   {'IdRef': 10063, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_obj_value(output, 1347)
# Out:
# {'ClassInfo': {'ObjectId': 1347,
#   'Name': 'System.Collections.Generic.List`1[[MapRuleLibrary.Party.CPersonalQuestState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#   'MemberCount': 3,
#   'MemberNames': ['_items', '_size', '_version']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['Class', 'Primitive', 'Primitive'],
#   'AdditionalInfos': [{'TypeName': 'MapRuleLibrary.Party.CPersonalQuestState[]',
#     'LibraryId': 2},
#    'Int32',
#    'Int32']},
#  'Values': [{'IdRef': 10064, 'RecordTypeEnum': 'MemberReference'}, 2, 0],
#  'RecordTypeEnum': 'SystemClassWithMembersAndTypes'}

# %%
get_obj_value(output, 10064)
# Out:
# {'ObjectId': 10064,
#  'BinaryArrayTypeEnum': 'Single',
#  'rank': 1,
#  'Lengths': [2],
#  'LowerBounds': [],
#  'TypeEnum': 'Class',
#  'AdditionalTypeInfo': {'TypeName': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'LibraryId': 2},
#  'Values': [{'IdRef': 27048, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1346, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'BinaryArray'}

# %%
get_obj_value(output, 27048)
# Out:
# {'ObjectId': 27048,
#  'MetadataId': 1346,
#  'Values': [{'ObjectId': 32829,
#    'Value': 'PERSONALQUEST_Greed_is_Good',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 32830, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 32831, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ObjectId': -32832,
#    'MetadataId': -10062,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'},
#   0,
#   0,
#   {'IdRef': 32833, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
chest_path = get_paths_to_value(output, "AlreadyRewardedChestTreasureTableIDs")[0]
chest_path
# Out:
# [0, 3, 'ClassInfo', 'MemberNames', 38, 'AlreadyRewardedChestTreasureTableIDs']

# %%
from unittest.mock import MagicMock
self = MagicMock()
self.json = output

# %%
get_obj_value(output, chest_idref)
# Out:
# {'ObjectId': 33,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 86, 'RecordTypeEnum': 'MemberReference'}, 11, 11],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
chest_idref = output[chest_path[0]][chest_path[1]]["Values"][chest_path[4]]["IdRef"]
chest_idref2 = get_obj_value(output, chest_idref)["Values"][0]["IdRef"]
chest_idref2
# Out:
# 86

# %%
struct.pack("<I",4294967295)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [297], line 1
# ----> 1 struct.pack("<I",23320492323423423)
#
# error: 'I' format requires 0 <= number <= 4294967295

# %%
a = b"65"
int(a)
# Out:
# 65

# %%
get_obj_value(output, 139)
# Out:
# {'ClassInfo': {'ObjectId': 139,
#   'Name': 'MapRuleLibrary.Party.CPartyAchievement',
#   'MemberCount': 9,
#   'MemberNames': ['ID',
#    'State',
#    'Rewards',
#    'RewardGenerationRNGState',
#    'UnlockedTimeStamp',
#    'RolledRewards',
#    'CompletedTimeStamp',
#    'UnlockConditionState',
#    'AchievementConditionState']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['String',
#    'Class',
#    'SystemClass',
#    'Object',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Class',
#    'Class'],
#   'AdditionalInfos': [None,
#    {'TypeName': 'MapRuleLibrary.Party.EAchievementState', 'LibraryId': 2},
#    'System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.RewardGroup, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#    None,
#    'DateTime',
#    'Boolean',
#    'DateTime',
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2},
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2}]},
#  'LibraryId': 2,
#  'Values': [{'ObjectId': 3627,
#    'Value': 'Achievement_CityRuleEconomic',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ClassInfo': {'ObjectId': -3628,
#     'Name': 'MapRuleLibrary.Party.EAchievementState',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [1],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'},
#   {'IdRef': 3629, 'RecordTypeEnum': 'MemberReference'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'Kind': None, 'ticks': 0},
#   False,
#   {'Kind': None, 'ticks': 0},
#   {'IdRef': 3630, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 3631, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_paths_to_value(output, 139)
# Out:
# [[0, 71, 'Values', 0, 'IdRef', 139],
#  [0, 105, 'ClassInfo', 'ObjectId', 139],
#  [0, 106, 'MetadataId', 139],
#  [0, 107, 'MetadataId', 139],
#  [0, 108, 'MetadataId', 139],
#  [0, 109, 'MetadataId', 139],
#  [0, 110, 'MetadataId', 139],
#  [0, 111, 'MetadataId', 139],
#  [0, 112, 'MetadataId', 139],
#  [0, 113, 'MetadataId', 139],
#  [0, 114, 'MetadataId', 139],
#  [0, 115, 'MetadataId', 139],
#  [0, 116, 'MetadataId', 139],
#  [0, 117, 'MetadataId', 139],
#  [0, 118, 'MetadataId', 139],
#  [0, 121, 'MetadataId', 139],
#  [0, 122, 'MetadataId', 139],
#  [0, 123, 'MetadataId', 139],
#  [0, 124, 'MetadataId', 139],
#  [0, 126, 'MetadataId', 139],
#  [0, 127, 'MetadataId', 139],
#  [0, 130, 'MetadataId', 139],
#  [0, 131, 'MetadataId', 139],
#  [0, 132, 'MetadataId', 139],
#  [0, 133, 'MetadataId', 139],
#  [0, 134, 'MetadataId', 139],
#  [0, 135, 'MetadataId', 139],
#  [0, 137, 'MetadataId', 139],
#  [0, 138, 'MetadataId', 139],
#  [0, 142, 'MetadataId', 139],
#  [0, 143, 'MetadataId', 139],
#  [0, 144, 'MetadataId', 139],
#  [0, 145, 'MetadataId', 139],
#  [0, 146, 'MetadataId', 139],
#  [0, 147, 'MetadataId', 139],
#  [0, 148, 'MetadataId', 139],
#  [0, 169, 'MetadataId', 139],
#  [0, 172, 'MetadataId', 139],
#  [0, 173, 'MetadataId', 139],
#  [0, 174, 'MetadataId', 139],
#  [0, 210, 'MetadataId', 139],
#  [0, 211, 'MetadataId', 139],
#  [0, 214, 'MetadataId', 139],
#  [0, 217, 'MetadataId', 139],
#  [0, 229, 'MetadataId', 139],
#  [0, 230, 'MetadataId', 139],
#  [0, 233, 'MetadataId', 139],
#  [0, 234, 'MetadataId', 139],
#  [0, 237, 'MetadataId', 139],
#  [0, 238, 'MetadataId', 139],
#  [0, 243, 'MetadataId', 139],
#  [0, 244, 'MetadataId', 139],
#  [0, 245, 'MetadataId', 139],
#  [0, 246, 'MetadataId', 139],
#  [0, 247, 'MetadataId', 139],
#  [0, 248, 'MetadataId', 139],
#  [0, 249, 'MetadataId', 139],
#  [0, 250, 'MetadataId', 139],
#  [0, 251, 'MetadataId', 139],
#  [0, 252, 'MetadataId', 139],
#  [0, 253, 'MetadataId', 139],
#  [0, 254, 'MetadataId', 139],
#  [0, 255, 'MetadataId', 139],
#  [0, 256, 'MetadataId', 139],
#  [0, 257, 'MetadataId', 139],
#  [0, 258, 'MetadataId', 139],
#  [0, 259, 'MetadataId', 139],
#  [0, 260, 'MetadataId', 139],
#  [0, 261, 'MetadataId', 139],
#  [0, 263, 'MetadataId', 139],
#  [0, 264, 'MetadataId', 139],
#  [0, 265, 'MetadataId', 139],
#  [0, 266, 'MetadataId', 139],
#  [0, 267, 'MetadataId', 139],
#  [0, 268, 'MetadataId', 139],
#  [0, 269, 'MetadataId', 139],
#  [0, 270, 'MetadataId', 139],
#  [0, 271, 'MetadataId', 139],
#  [0, 272, 'MetadataId', 139],
#  [0, 273, 'MetadataId', 139],
#  [0, 274, 'MetadataId', 139],
#  [0, 275, 'MetadataId', 139],
#  [0, 276, 'MetadataId', 139],
#  [0, 277, 'MetadataId', 139],
#  [0, 278, 'MetadataId', 139],
#  [0, 279, 'MetadataId', 139],
#  [0, 280, 'MetadataId', 139],
#  [0, 281, 'MetadataId', 139],
#  [0, 282, 'MetadataId', 139],
#  [0, 283, 'MetadataId', 139],
#  [0, 284, 'MetadataId', 139],
#  [0, 285, 'MetadataId', 139],
#  [0, 286, 'MetadataId', 139],
#  [0, 287, 'MetadataId', 139],
#  [0, 288, 'MetadataId', 139],
#  [0, 289, 'MetadataId', 139],
#  [0, 290, 'MetadataId', 139],
#  [0, 291, 'MetadataId', 139],
#  [0, 292, 'MetadataId', 139],
#  [0, 293, 'MetadataId', 139],
#  [0, 294, 'MetadataId', 139],
#  [0, 295, 'MetadataId', 139],
#  [0, 296, 'MetadataId', 139],
#  [0, 297, 'MetadataId', 139],
#  [0, 298, 'MetadataId', 139],
#  [0, 299, 'MetadataId', 139],
#  [0, 300, 'MetadataId', 139],
#  [0, 301, 'MetadataId', 139],
#  [0, 302, 'MetadataId', 139],
#  [0, 303, 'MetadataId', 139],
#  [0, 304, 'MetadataId', 139],
#  [0, 305, 'MetadataId', 139],
#  [0, 306, 'MetadataId', 139],
#  [0, 307, 'MetadataId', 139],
#  [0, 308, 'MetadataId', 139],
#  [0, 310, 'MetadataId', 139],
#  [0, 311, 'MetadataId', 139],
#  [0, 312, 'MetadataId', 139],
#  [0, 314, 'MetadataId', 139],
#  [0, 315, 'MetadataId', 139],
#  [0, 316, 'MetadataId', 139],
#  [0, 317, 'MetadataId', 139],
#  [0, 318, 'MetadataId', 139],
#  [0, 319, 'MetadataId', 139],
#  [0, 320, 'MetadataId', 139],
#  [0, 321, 'MetadataId', 139],
#  [0, 322, 'MetadataId', 139],
#  [0, 323, 'MetadataId', 139],
#  [0, 324, 'MetadataId', 139],
#  [0, 325, 'MetadataId', 139],
#  [0, 326, 'MetadataId', 139],
#  [0, 327, 'MetadataId', 139],
#  [0, 328, 'MetadataId', 139],
#  [0, 329, 'MetadataId', 139],
#  [0, 330, 'MetadataId', 139],
#  [0, 331, 'MetadataId', 139],
#  [0, 332, 'MetadataId', 139],
#  [0, 333, 'MetadataId', 139],
#  [0, 334, 'MetadataId', 139],
#  [0, 335, 'MetadataId', 139],
#  [0, 336, 'MetadataId', 139],
#  [0, 337, 'MetadataId', 139],
#  [0, 338, 'MetadataId', 139],
#  [0, 339, 'MetadataId', 139],
#  [0, 340, 'MetadataId', 139],
#  [0, 341, 'MetadataId', 139],
#  [0, 342, 'MetadataId', 139],
#  [0, 343, 'MetadataId', 139],
#  [0, 344, 'MetadataId', 139],
#  [0, 345, 'MetadataId', 139],
#  [0, 346, 'MetadataId', 139],
#  [0, 347, 'MetadataId', 139],
#  [0, 348, 'MetadataId', 139],
#  [0, 349, 'MetadataId', 139],
#  [0, 350, 'MetadataId', 139],
#  [0, 351, 'MetadataId', 139],
#  [0, 352, 'MetadataId', 139],
#  [0, 353, 'MetadataId', 139],
#  [0, 354, 'MetadataId', 139],
#  [0, 355, 'MetadataId', 139],
#  [0, 356, 'MetadataId', 139],
#  [0, 357, 'MetadataId', 139],
#  [0, 358, 'MetadataId', 139],
#  [0, 359, 'MetadataId', 139],
#  [0, 360, 'MetadataId', 139],
#  [0, 361, 'MetadataId', 139],
#  [0, 362, 'MetadataId', 139],
#  [0, 363, 'MetadataId', 139],
#  [0, 364, 'MetadataId', 139],
#  [0, 365, 'MetadataId', 139],
#  [0, 366, 'MetadataId', 139],
#  [0, 367, 'MetadataId', 139],
#  [0, 368, 'MetadataId', 139],
#  [0, 369, 'MetadataId', 139],
#  [0, 370, 'MetadataId', 139],
#  [0, 371, 'MetadataId', 139],
#  [0, 372, 'MetadataId', 139],
#  [0, 373, 'MetadataId', 139],
#  [0, 374, 'MetadataId', 139],
#  [0, 375, 'MetadataId', 139],
#  [0, 376, 'MetadataId', 139],
#  [0, 377, 'MetadataId', 139],
#  [0, 378, 'MetadataId', 139],
#  [0, 379, 'MetadataId', 139],
#  [0, 380, 'MetadataId', 139],
#  [0, 381, 'MetadataId', 139],
#  [0, 382, 'MetadataId', 139],
#  [0, 383, 'MetadataId', 139],
#  [0, 384, 'MetadataId', 139],
#  [0, 385, 'MetadataId', 139],
#  [0, 386, 'MetadataId', 139],
#  [0, 387, 'MetadataId', 139],
#  [0, 388, 'MetadataId', 139],
#  [0, 389, 'MetadataId', 139],
#  [0, 390, 'MetadataId', 139],
#  [0, 391, 'MetadataId', 139],
#  [0, 392, 'MetadataId', 139],
#  [0, 393, 'MetadataId', 139],
#  [0, 394, 'MetadataId', 139],
#  [0, 395, 'MetadataId', 139],
#  [0, 396, 'MetadataId', 139],
#  [0, 397, 'MetadataId', 139],
#  [0, 398, 'MetadataId', 139],
#  [0, 399, 'MetadataId', 139],
#  [0, 400, 'MetadataId', 139],
#  [0, 401, 'MetadataId', 139],
#  [0, 402, 'MetadataId', 139],
#  [0, 403, 'MetadataId', 139],
#  [0, 404, 'MetadataId', 139],
#  [0, 405, 'MetadataId', 139],
#  [0, 406, 'MetadataId', 139],
#  [0, 407, 'MetadataId', 139],
#  [0, 408, 'MetadataId', 139],
#  [0, 409, 'MetadataId', 139],
#  [0, 410, 'MetadataId', 139],
#  [0, 411, 'MetadataId', 139],
#  [0, 412, 'MetadataId', 139],
#  [0, 413, 'MetadataId', 139],
#  [0, 414, 'MetadataId', 139],
#  [0, 415, 'MetadataId', 139],
#  [0, 416, 'MetadataId', 139],
#  [0, 417, 'MetadataId', 139],
#  [0, 418, 'MetadataId', 139],
#  [0, 419, 'MetadataId', 139],
#  [0, 420, 'MetadataId', 139],
#  [0, 421, 'MetadataId', 139],
#  [0, 422, 'MetadataId', 139],
#  [0, 423, 'MetadataId', 139],
#  [0, 424, 'MetadataId', 139],
#  [0, 425, 'MetadataId', 139],
#  [0, 426, 'MetadataId', 139],
#  [0, 427, 'MetadataId', 139],
#  [0, 428, 'MetadataId', 139],
#  [0, 429, 'MetadataId', 139],
#  [0, 430, 'MetadataId', 139],
#  [0, 431, 'MetadataId', 139],
#  [0, 432, 'MetadataId', 139],
#  [0, 433, 'MetadataId', 139],
#  [0, 434, 'MetadataId', 139],
#  [0, 435, 'MetadataId', 139],
#  [0, 436, 'MetadataId', 139],
#  [0, 437, 'MetadataId', 139],
#  [0, 438, 'MetadataId', 139],
#  [0, 439, 'MetadataId', 139],
#  [0, 440, 'MetadataId', 139],
#  [0, 441, 'MetadataId', 139],
#  [0, 442, 'MetadataId', 139],
#  [0, 443, 'MetadataId', 139],
#  [0, 444, 'MetadataId', 139],
#  [0, 445, 'MetadataId', 139],
#  [0, 446, 'MetadataId', 139],
#  [0, 447, 'MetadataId', 139],
#  [0, 448, 'MetadataId', 139],
#  [0, 449, 'MetadataId', 139],
#  [0, 450, 'MetadataId', 139],
#  [0, 451, 'MetadataId', 139],
#  [0, 452, 'MetadataId', 139],
#  [0, 453, 'MetadataId', 139],
#  [0, 454, 'MetadataId', 139],
#  [0, 455, 'MetadataId', 139],
#  [0, 456, 'MetadataId', 139],
#  [0, 457, 'MetadataId', 139],
#  [0, 458, 'MetadataId', 139],
#  [0, 459, 'MetadataId', 139],
#  [0, 460, 'MetadataId', 139],
#  [0, 461, 'MetadataId', 139],
#  [0, 462, 'MetadataId', 139],
#  [0, 463, 'MetadataId', 139],
#  [0, 464, 'MetadataId', 139],
#  [0, 465, 'MetadataId', 139],
#  [0, 466, 'MetadataId', 139],
#  [0, 467, 'MetadataId', 139],
#  [0, 468, 'MetadataId', 139],
#  [0, 469, 'MetadataId', 139],
#  [0, 470, 'MetadataId', 139],
#  [0, 473, 'MetadataId', 139],
#  [0, 474, 'MetadataId', 139],
#  [0, 475, 'MetadataId', 139],
#  [0, 476, 'MetadataId', 139],
#  [0, 479, 'MetadataId', 139],
#  [0, 480, 'MetadataId', 139],
#  [0, 481, 'MetadataId', 139],
#  [0, 482, 'MetadataId', 139],
#  [0, 483, 'MetadataId', 139],
#  [0, 484, 'MetadataId', 139],
#  [0, 489, 'MetadataId', 139],
#  [0, 490, 'MetadataId', 139],
#  [0, 491, 'MetadataId', 139],
#  [0, 492, 'MetadataId', 139],
#  [0, 493, 'MetadataId', 139],
#  [0, 494, 'MetadataId', 139],
#  [0, 497, 'MetadataId', 139],
#  [0, 498, 'MetadataId', 139],
#  [0, 499, 'MetadataId', 139],
#  [0, 500, 'MetadataId', 139],
#  [0, 501, 'MetadataId', 139],
#  [0, 502, 'MetadataId', 139],
#  [0, 503, 'MetadataId', 139],
#  [0, 504, 'MetadataId', 139],
#  [0, 507, 'MetadataId', 139],
#  [0, 508, 'MetadataId', 139],
#  [0, 509, 'MetadataId', 139],
#  [0, 510, 'MetadataId', 139],
#  [0, 511, 'MetadataId', 139],
#  [0, 512, 'MetadataId', 139],
#  [0, 513, 'MetadataId', 139],
#  [0, 514, 'MetadataId', 139],
#  [0, 515, 'MetadataId', 139],
#  [0, 516, 'MetadataId', 139],
#  [0, 519, 'MetadataId', 139],
#  [0, 520, 'MetadataId', 139],
#  [0, 521, 'MetadataId', 139],
#  [0, 522, 'MetadataId', 139],
#  [0, 523, 'MetadataId', 139],
#  [0, 524, 'MetadataId', 139],
#  [0, 525, 'MetadataId', 139],
#  [0, 526, 'MetadataId', 139],
#  [0, 527, 'MetadataId', 139],
#  [0, 528, 'MetadataId', 139],
#  [0, 531, 'MetadataId', 139],
#  [0, 532, 'MetadataId', 139],
#  [0, 533, 'MetadataId', 139],
#  [0, 534, 'MetadataId', 139],
#  [0, 535, 'MetadataId', 139],
#  [0, 536, 'MetadataId', 139],
#  [0, 546, 'MetadataId', 139],
#  [0, 547, 'MetadataId', 139],
#  [0, 548, 'MetadataId', 139],
#  [0, 549, 'MetadataId', 139],
#  [0, 550, 'MetadataId', 139],
#  [0, 551, 'MetadataId', 139],
#  [0, 552, 'MetadataId', 139],
#  [0, 553, 'MetadataId', 139],
#  [0, 554, 'MetadataId', 139],
#  [0, 555, 'MetadataId', 139],
#  [0, 556, 'MetadataId', 139],
#  [0, 557, 'MetadataId', 139],
#  [0, 558, 'MetadataId', 139],
#  [0, 559, 'MetadataId', 139],
#  [0, 560, 'MetadataId', 139],
#  [0, 561, 'MetadataId', 139],
#  [0, 562, 'MetadataId', 139],
#  [0, 563, 'MetadataId', 139],
#  [0, 576, 'MetadataId', 139],
#  [0, 577, 'MetadataId', 139],
#  [0, 578, 'MetadataId', 139],
#  [0, 579, 'MetadataId', 139],
#  [0, 580, 'MetadataId', 139],
#  [0, 581, 'MetadataId', 139],
#  [0, 582, 'MetadataId', 139],
#  [0, 583, 'MetadataId', 139],
#  [0, 584, 'MetadataId', 139],
#  [0, 585, 'MetadataId', 139],
#  [0, 586, 'MetadataId', 139],
#  [0, 587, 'MetadataId', 139],
#  [0, 588, 'MetadataId', 139],
#  [0, 589, 'MetadataId', 139],
#  [0, 590, 'MetadataId', 139],
#  [0, 591, 'MetadataId', 139],
#  [0, 592, 'MetadataId', 139],
#  [0, 593, 'MetadataId', 139],
#  [0, 594, 'MetadataId', 139],
#  [0, 595, 'MetadataId', 139],
#  [0, 596, 'MetadataId', 139],
#  [0, 597, 'MetadataId', 139],
#  [0, 598, 'MetadataId', 139],
#  [0, 599, 'MetadataId', 139],
#  [0, 600, 'MetadataId', 139],
#  [0, 601, 'MetadataId', 139],
#  [0, 602, 'MetadataId', 139],
#  [0, 603, 'MetadataId', 139],
#  [0, 604, 'MetadataId', 139],
#  [0, 605, 'MetadataId', 139],
#  [0, 606, 'MetadataId', 139],
#  [0, 607, 'MetadataId', 139],
#  [0, 608, 'MetadataId', 139],
#  [0, 609, 'MetadataId', 139],
#  [0, 610, 'MetadataId', 139],
#  [0, 611, 'MetadataId', 139],
#  [0, 612, 'MetadataId', 139],
#  [0, 613, 'MetadataId', 139],
#  [0, 614, 'MetadataId', 139],
#  [0, 615, 'MetadataId', 139],
#  [0, 616, 'MetadataId', 139],
#  [0, 617, 'MetadataId', 139],
#  [0, 618, 'MetadataId', 139],
#  [0, 619, 'MetadataId', 139],
#  [0, 620, 'MetadataId', 139],
#  [0, 621, 'MetadataId', 139],
#  [0, 622, 'MetadataId', 139],
#  [0, 623, 'MetadataId', 139],
#  [0, 624, 'MetadataId', 139],
#  [0, 625, 'MetadataId', 139],
#  [0, 626, 'MetadataId', 139],
#  [0, 627, 'MetadataId', 139],
#  [0, 630, 'MetadataId', 139],
#  [0, 631, 'MetadataId', 139],
#  [0, 632, 'MetadataId', 139],
#  [0, 633, 'MetadataId', 139],
#  [0, 636, 'MetadataId', 139],
#  [0, 639, 'MetadataId', 139],
#  [0, 640, 'MetadataId', 139],
#  [0, 641, 'MetadataId', 139],
#  [0, 642, 'MetadataId', 139],
#  [0, 645, 'MetadataId', 139],
#  [0, 648, 'MetadataId', 139],
#  [0, 649, 'MetadataId', 139],
#  [0, 650, 'MetadataId', 139],
#  [0, 651, 'MetadataId', 139],
#  [0, 652, 'MetadataId', 139],
#  [0, 653, 'MetadataId', 139],
#  [0, 654, 'MetadataId', 139],
#  [0, 657, 'MetadataId', 139],
#  [0, 660, 'MetadataId', 139],
#  [0, 663, 'MetadataId', 139],
#  [0, 666, 'MetadataId', 139],
#  [0, 669, 'MetadataId', 139],
#  [0, 670, 'MetadataId', 139],
#  [0, 671, 'MetadataId', 139],
#  [0, 672, 'MetadataId', 139],
#  [0, 673, 'MetadataId', 139],
#  [0, 674, 'MetadataId', 139],
#  [0, 675, 'MetadataId', 139],
#  [0, 678, 'MetadataId', 139],
#  [0, 679, 'MetadataId', 139],
#  [0, 680, 'MetadataId', 139],
#  [0, 681, 'MetadataId', 139],
#  [0, 682, 'MetadataId', 139],
#  [0, 683, 'MetadataId', 139],
#  [0, 684, 'MetadataId', 139],
#  [0, 685, 'MetadataId', 139],
#  [0, 686, 'MetadataId', 139],
#  [0, 687, 'MetadataId', 139],
#  [0, 688, 'MetadataId', 139],
#  [0, 689, 'MetadataId', 139],
#  [0, 690, 'MetadataId', 139],
#  [0, 691, 'MetadataId', 139],
#  [0, 692, 'MetadataId', 139],
#  [0, 693, 'MetadataId', 139],
#  [0, 694, 'MetadataId', 139],
#  [0, 695, 'MetadataId', 139],
#  [0, 696, 'MetadataId', 139],
#  [0, 697, 'MetadataId', 139],
#  [0, 698, 'MetadataId', 139],
#  [0, 699, 'MetadataId', 139],
#  [0, 700, 'MetadataId', 139],
#  [0, 701, 'MetadataId', 139],
#  [0, 702, 'MetadataId', 139],
#  [0, 703, 'MetadataId', 139],
#  [0, 704, 'MetadataId', 139],
#  [0, 705, 'MetadataId', 139],
#  [0, 708, 'MetadataId', 139],
#  [0, 709, 'MetadataId', 139],
#  [0, 710, 'MetadataId', 139],
#  [0, 711, 'MetadataId', 139],
#  [0, 712, 'MetadataId', 139],
#  [0, 713, 'MetadataId', 139],
#  [0, 714, 'MetadataId', 139],
#  [0, 715, 'MetadataId', 139],
#  [0, 716, 'MetadataId', 139],
#  [0, 717, 'MetadataId', 139],
#  [0, 718, 'MetadataId', 139],
#  [0, 719, 'MetadataId', 139],
#  [0, 720, 'MetadataId', 139],
#  [0, 721, 'MetadataId', 139],
#  [0, 722, 'MetadataId', 139],
#  [0, 723, 'MetadataId', 139],
#  [0, 724, 'MetadataId', 139],
#  [0, 725, 'MetadataId', 139],
#  [0, 726, 'MetadataId', 139],
#  [0, 727, 'MetadataId', 139],
#  [0, 728, 'MetadataId', 139],
#  [0, 729, 'MetadataId', 139],
#  [0, 730, 'MetadataId', 139],
#  [0, 731, 'MetadataId', 139],
#  [0, 732, 'MetadataId', 139],
#  [0, 733, 'MetadataId', 139],
#  [0, 734, 'MetadataId', 139],
#  [0, 735, 'MetadataId', 139],
#  [0, 736, 'MetadataId', 139],
#  [0, 737, 'MetadataId', 139],
#  [0, 738, 'MetadataId', 139],
#  [0, 739, 'MetadataId', 139],
#  [0, 740, 'MetadataId', 139],
#  [0, 741, 'MetadataId', 139],
#  [0, 742, 'MetadataId', 139],
#  [0, 743, 'MetadataId', 139],
#  [0, 744, 'MetadataId', 139],
#  [0, 745, 'MetadataId', 139],
#  [0, 746, 'MetadataId', 139],
#  [0, 747, 'MetadataId', 139],
#  [0, 750, 'MetadataId', 139],
#  [0, 751, 'MetadataId', 139],
#  [0, 752, 'MetadataId', 139],
#  [0, 753, 'MetadataId', 139],
#  [0, 754, 'MetadataId', 139],
#  [0, 755, 'MetadataId', 139],
#  [0, 756, 'MetadataId', 139],
#  [0, 759, 'MetadataId', 139],
#  [0, 760, 'MetadataId', 139],
#  [0, 761, 'MetadataId', 139],
#  [0, 762, 'MetadataId', 139],
#  [0, 765, 'MetadataId', 139],
#  [0, 766, 'MetadataId', 139],
#  [0, 767, 'MetadataId', 139],
#  [0, 768, 'MetadataId', 139],
#  [0, 769, 'MetadataId', 139],
#  [0, 770, 'MetadataId', 139],
#  [0, 771, 'MetadataId', 139],
#  [0, 772, 'MetadataId', 139],
#  [0, 773, 'MetadataId', 139],
#  [0, 774, 'MetadataId', 139],
#  [0, 775, 'MetadataId', 139],
#  [0, 776, 'MetadataId', 139],
#  [0, 777, 'MetadataId', 139],
#  [0, 778, 'MetadataId', 139],
#  [0, 779, 'MetadataId', 139],
#  [0, 780, 'MetadataId', 139],
#  [0, 781, 'MetadataId', 139],
#  [0, 782, 'MetadataId', 139],
#  [0, 783, 'MetadataId', 139],
#  [0, 784, 'MetadataId', 139],
#  [0, 786, 'MetadataId', 139],
#  [0, 788, 'MetadataId', 139],
#  [0, 790, 'MetadataId', 139],
#  [0, 792, 'MetadataId', 139],
#  [0, 794, 'MetadataId', 139],
#  [0, 796, 'MetadataId', 139],
#  [0, 798, 'MetadataId', 139],
#  [0, 800, 'MetadataId', 139],
#  [0, 802, 'MetadataId', 139],
#  [0, 804, 'MetadataId', 139],
#  [0, 806, 'MetadataId', 139],
#  [0, 808, 'MetadataId', 139],
#  [0, 810, 'MetadataId', 139],
#  [0, 812, 'MetadataId', 139],
#  [0, 814, 'MetadataId', 139],
#  [0, 816, 'MetadataId', 139],
#  [0, 818, 'MetadataId', 139],
#  [0, 820, 'MetadataId', 139],
#  [0, 822, 'MetadataId', 139],
#  [0, 824, 'MetadataId', 139],
#  [0, 826, 'MetadataId', 139],
#  [0, 828, 'MetadataId', 139],
#  [0, 830, 'MetadataId', 139],
#  [0, 832, 'MetadataId', 139],
#  [0, 834, 'MetadataId', 139],
#  [0, 836, 'MetadataId', 139],
#  [0, 838, 'MetadataId', 139],
#  [0, 840, 'MetadataId', 139],
#  [0, 842, 'MetadataId', 139],
#  [0, 844, 'MetadataId', 139],
#  [0, 846, 'MetadataId', 139],
#  [0, 848, 'MetadataId', 139],
#  [0, 850, 'MetadataId', 139],
#  [0, 852, 'MetadataId', 139],
#  [0, 854, 'MetadataId', 139],
#  [0, 856, 'MetadataId', 139],
#  [0, 858, 'MetadataId', 139],
#  [0, 860, 'MetadataId', 139],
#  [0, 862, 'MetadataId', 139],
#  [0, 864, 'MetadataId', 139],
#  [0, 866, 'MetadataId', 139],
#  [0, 868, 'MetadataId', 139],
#  [0, 870, 'MetadataId', 139],
#  [0, 872, 'MetadataId', 139],
#  [0, 874, 'MetadataId', 139],
#  [0, 876, 'MetadataId', 139],
#  [0, 878, 'MetadataId', 139],
#  [0, 880, 'MetadataId', 139],
#  [0, 882, 'MetadataId', 139],
#  [0, 884, 'MetadataId', 139],
#  [0, 886, 'MetadataId', 139],
#  [0, 888, 'MetadataId', 139],
#  [0, 890, 'MetadataId', 139],
#  [0, 892, 'MetadataId', 139],
#  [0, 894, 'MetadataId', 139],
#  [0, 896, 'MetadataId', 139],
#  [0, 898, 'MetadataId', 139],
#  [0, 900, 'MetadataId', 139],
#  [0, 902, 'MetadataId', 139],
#  [0, 904, 'MetadataId', 139],
#  [0, 906, 'MetadataId', 139],
#  [0, 908, 'MetadataId', 139],
#  [0, 910, 'MetadataId', 139],
#  [0, 912, 'MetadataId', 139],
#  [0, 914, 'MetadataId', 139],
#  [0, 916, 'MetadataId', 139],
#  [0, 918, 'MetadataId', 139],
#  [0, 920, 'MetadataId', 139],
#  [0, 922, 'MetadataId', 139],
#  [0, 924, 'MetadataId', 139],
#  [0, 926, 'MetadataId', 139],
#  [0, 928, 'MetadataId', 139],
#  [0, 930, 'MetadataId', 139],
#  [0, 932, 'MetadataId', 139],
#  [0, 934, 'MetadataId', 139],
#  [0, 936, 'MetadataId', 139],
#  [0, 938, 'MetadataId', 139],
#  [0, 940, 'MetadataId', 139],
#  [0, 942, 'MetadataId', 139],
#  [0, 944, 'MetadataId', 139],
#  [0, 946, 'MetadataId', 139],
#  [0, 948, 'MetadataId', 139],
#  [0, 949, 'MetadataId', 139],
#  [0, 952, 'MetadataId', 139],
#  [0, 955, 'MetadataId', 139],
#  [0, 958, 'MetadataId', 139],
#  [0, 961, 'MetadataId', 139],
#  [0, 964, 'MetadataId', 139],
#  [0, 967, 'MetadataId', 139],
#  [0, 970, 'MetadataId', 139],
#  [0, 973, 'MetadataId', 139],
#  [0, 976, 'MetadataId', 139],
#  [0, 979, 'MetadataId', 139],
#  [0, 982, 'MetadataId', 139],
#  [0, 985, 'MetadataId', 139],
#  [0, 988, 'MetadataId', 139],
#  [0, 991, 'MetadataId', 139],
#  [0, 994, 'MetadataId', 139],
#  [0, 997, 'MetadataId', 139],
#  [0, 1000, 'MetadataId', 139],
#  [0, 1003, 'MetadataId', 139],
#  [0, 1006, 'MetadataId', 139],
#  [0, 1009, 'MetadataId', 139],
#  [0, 1012, 'MetadataId', 139],
#  [0, 1015, 'MetadataId', 139],
#  [0, 1018, 'MetadataId', 139],
#  [0, 1021, 'MetadataId', 139],
#  [0, 1024, 'MetadataId', 139],
#  [0, 1027, 'MetadataId', 139],
#  [0, 1030, 'MetadataId', 139],
#  [0, 1033, 'MetadataId', 139],
#  [0, 1036, 'MetadataId', 139],
#  [0, 1039, 'MetadataId', 139],
#  [0, 1042, 'MetadataId', 139],
#  [0, 1043, 'MetadataId', 139],
#  [0, 1044, 'MetadataId', 139],
#  [0, 1045, 'MetadataId', 139],
#  [0, 1048, 'MetadataId', 139],
#  [0, 1051, 'MetadataId', 139],
#  [0, 1052, 'MetadataId', 139],
#  [0, 1053, 'MetadataId', 139],
#  [0, 1054, 'MetadataId', 139],
#  [0, 1057, 'MetadataId', 139],
#  [0, 1060, 'MetadataId', 139],
#  [0, 1061, 'MetadataId', 139],
#  [0, 1062, 'MetadataId', 139],
#  [0, 1063, 'MetadataId', 139],
#  [0, 1064, 'MetadataId', 139],
#  [0, 1065, 'MetadataId', 139],
#  [0, 1066, 'MetadataId', 139],
#  [0, 1069, 'MetadataId', 139],
#  [0, 1072, 'MetadataId', 139],
#  [0, 1075, 'MetadataId', 139],
#  [0, 1078, 'MetadataId', 139],
#  [0, 1081, 'MetadataId', 139],
#  [0, 1082, 'MetadataId', 139],
#  [0, 1083, 'MetadataId', 139],
#  [0, 1084, 'MetadataId', 139],
#  [0, 1085, 'MetadataId', 139],
#  [0, 1086, 'MetadataId', 139],
#  [0, 1087, 'MetadataId', 139],
#  [0, 1090, 'MetadataId', 139],
#  [0, 1091, 'MetadataId', 139],
#  [0, 1092, 'MetadataId', 139],
#  [0, 1093, 'MetadataId', 139],
#  [0, 1094, 'MetadataId', 139],
#  [0, 1095, 'MetadataId', 139],
#  [0, 1096, 'MetadataId', 139],
#  [0, 1097, 'MetadataId', 139],
#  [0, 1098, 'MetadataId', 139],
#  [0, 1099, 'MetadataId', 139],
#  [0, 1100, 'MetadataId', 139],
#  [0, 1101, 'MetadataId', 139],
#  [0, 1102, 'MetadataId', 139],
#  [0, 1103, 'MetadataId', 139],
#  [0, 1104, 'MetadataId', 139],
#  [0, 1105, 'MetadataId', 139],
#  [0, 1106, 'MetadataId', 139],
#  [0, 1107, 'MetadataId', 139],
#  [0, 1108, 'MetadataId', 139],
#  [0, 1109, 'MetadataId', 139],
#  [0, 1110, 'MetadataId', 139],
#  [0, 1111, 'MetadataId', 139],
#  [0, 1112, 'MetadataId', 139],
#  [0, 1113, 'MetadataId', 139],
#  [0, 1114, 'MetadataId', 139],
#  [0, 1115, 'MetadataId', 139],
#  [0, 1116, 'MetadataId', 139],
#  [0, 1117, 'MetadataId', 139],
#  [0, 1120, 'MetadataId', 139],
#  [0, 1121, 'MetadataId', 139],
#  [0, 1122, 'MetadataId', 139],
#  [0, 1123, 'MetadataId', 139],
#  [0, 1124, 'MetadataId', 139],
#  [0, 1125, 'MetadataId', 139],
#  [0, 1126, 'MetadataId', 139],
#  [0, 1127, 'MetadataId', 139],
#  [0, 1128, 'MetadataId', 139],
#  [0, 1129, 'MetadataId', 139],
#  [0, 1130, 'MetadataId', 139],
#  [0, 1131, 'MetadataId', 139],
#  [0, 1132, 'MetadataId', 139],
#  [0, 1133, 'MetadataId', 139],
#  [0, 1134, 'MetadataId', 139],
#  [0, 1135, 'MetadataId', 139],
#  [0, 1136, 'MetadataId', 139],
#  [0, 1137, 'MetadataId', 139],
#  [0, 1138, 'MetadataId', 139],
#  [0, 1139, 'MetadataId', 139],
#  [0, 1140, 'MetadataId', 139],
#  [0, 1141, 'MetadataId', 139],
#  [0, 1142, 'MetadataId', 139],
#  [0, 1143, 'MetadataId', 139],
#  [0, 1144, 'MetadataId', 139],
#  [0, 1145, 'MetadataId', 139],
#  [0, 1146, 'MetadataId', 139],
#  [0, 1147, 'MetadataId', 139],
#  [0, 1150, 'MetadataId', 139],
#  [0, 1151, 'MetadataId', 139],
#  [0, 1152, 'MetadataId', 139],
#  [0, 1153, 'MetadataId', 139],
#  [0, 1154, 'MetadataId', 139],
#  [0, 1155, 'MetadataId', 139],
#  [0, 1157, 'MetadataId', 139],
#  [0, 1159, 'MetadataId', 139],
#  [0, 1161, 'MetadataId', 139],
#  [0, 1163, 'MetadataId', 139],
#  [0, 1165, 'MetadataId', 139],
#  [0, 1167, 'MetadataId', 139],
#  [0, 1169, 'MetadataId', 139],
#  [0, 1171, 'MetadataId', 139],
#  [0, 1173, 'MetadataId', 139],
#  [0, 1175, 'MetadataId', 139],
#  [0, 1177, 'MetadataId', 139],
#  [0, 1179, 'MetadataId', 139],
#  [0, 1181, 'MetadataId', 139],
#  [0, 1183, 'MetadataId', 139],
#  [0, 1185, 'MetadataId', 139],
#  [0, 1187, 'MetadataId', 139],
#  [0, 1189, 'MetadataId', 139],
#  [0, 1191, 'MetadataId', 139],
#  [0, 1193, 'MetadataId', 139],
#  [0, 1195, 'MetadataId', 139],
#  [0, 1197, 'MetadataId', 139],
#  [0, 1199, 'MetadataId', 139],
#  [0, 1201, 'MetadataId', 139],
#  [0, 1203, 'MetadataId', 139],
#  [0, 1205, 'MetadataId', 139],
#  [0, 1207, 'MetadataId', 139],
#  [0, 1209, 'MetadataId', 139],
#  [0, 1211, 'MetadataId', 139],
#  [0, 1213, 'MetadataId', 139],
#  [0, 1215, 'MetadataId', 139],
#  [0, 1217, 'MetadataId', 139],
#  [0, 1219, 'MetadataId', 139],
#  [0, 1221, 'MetadataId', 139],
#  [0, 1223, 'MetadataId', 139],
#  [0, 1225, 'MetadataId', 139],
#  [0, 1227, 'MetadataId', 139],
#  [0, 1229, 'MetadataId', 139],
#  [0, 1231, 'MetadataId', 139],
#  [0, 1233, 'MetadataId', 139],
#  [0, 1235, 'MetadataId', 139],
#  [0, 1237, 'MetadataId', 139],
#  [0, 1239, 'MetadataId', 139],
#  [0, 1241, 'MetadataId', 139],
#  [0, 1243, 'MetadataId', 139],
#  [0, 1245, 'MetadataId', 139],
#  [0, 1247, 'MetadataId', 139],
#  [0, 1249, 'MetadataId', 139],
#  [0, 1251, 'MetadataId', 139],
#  [0, 1253, 'MetadataId', 139],
#  [0, 1255, 'MetadataId', 139],
#  [0, 1257, 'MetadataId', 139],
#  [0, 1259, 'MetadataId', 139],
#  [0, 1261, 'MetadataId', 139],
#  [0, 1263, 'MetadataId', 139],
#  [0, 1265, 'MetadataId', 139],
#  [0, 1267, 'MetadataId', 139],
#  [0, 1269, 'MetadataId', 139],
#  [0, 1271, 'MetadataId', 139],
#  [0, 1273, 'MetadataId', 139],
#  [0, 1275, 'MetadataId', 139],
#  [0, 1277, 'MetadataId', 139],
#  [0, 1279, 'MetadataId', 139],
#  [0, 1281, 'MetadataId', 139],
#  [0, 1283, 'MetadataId', 139],
#  [0, 1285, 'MetadataId', 139],
#  [0, 1287, 'MetadataId', 139],
#  [0, 1289, 'MetadataId', 139],
#  [0, 1291, 'MetadataId', 139],
#  [0, 1293, 'MetadataId', 139],
#  [0, 1295, 'MetadataId', 139],
#  [0, 1568, 'Values', 10, 139],
#  [0, 7813, 'Values', 287, 139],
#  [0, 7819, 'Values', 286, 139],
#  [0, 7855, 'Values', 346, 139],
#  [0, 7891, 'Values', 391, 139],
#  [0, 8059, 'Values', 391, 139],
#  [0, 8081, 'Values', 346, 139],
#  [0, 8111, 'Values', 287, 139],
#  [0, 8201, 'Values', 350, 139],
#  [0, 8207, 'Values', 350, 139],
#  [0, 8213, 'Values', 350, 139],
#  [0, 8219, 'Values', 350, 139],
#  [0, 8225, 'Values', 350, 139],
#  [0, 8231, 'Values', 350, 139],
#  [0, 8237, 'Values', 350, 139],
#  [0, 8243, 'Values', 350, 139],
#  [0, 8249, 'Values', 350, 139],
#  [0, 8255, 'Values', 350, 139],
#  [0, 8261, 'Values', 350, 139],
#  [0, 8267, 'Values', 350, 139],
#  [0, 8273, 'Values', 350, 139],
#  [0, 8285, 'Values', 185, 139],
#  [0, 8333, 'Values', 273, 139],
#  [0, 8339, 'Values', 273, 139],
#  [0, 8361, 'Values', 291, 139],
#  [0, 8367, 'Values', 291, 139],
#  [0, 8423, 'Values', 291, 139],
#  [0, 8429, 'Values', 291, 139],
#  [0, 8463, 'Values', 273, 139],
 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
output[0][5]["Values"][6]
# Out:
# {'IdRef': 38, 'RecordTypeEnum': 'MemberReference'}

# %%
get_paths_to_value(output, "PersonalQuestDeck")
# Out:
# [[0, 5, 'ClassInfo', 'MemberNames', 6, 'PersonalQuestDeck']]

# %%
get_obj_value(output, 38)
# Out:
# {'ObjectId': 38,
#  'MetadataId': 36,
#  'Values': [{'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 95, 'RecordTypeEnum': 'MemberReference'},
#   {'ObjectId': -96,
#    'MetadataId': -90,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 36)
# Out:
# {'ClassInfo': {'ObjectId': 36,
#   'Name': 'MapRuleLibrary.YML.Events.CCardDeck',
#   'MemberCount': 4,
#   'MemberNames': ['m_InitialCards',
#    'm_Cards',
#    'm_DiscardedCards',
#    'm_NeedsShuffle']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['SystemClass',
#    'SystemClass',
#    'SystemClass',
#    'Class'],
#   'AdditionalInfos': ['System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    {'TypeName': 'MapRuleLibrary.YML.Events.CCardDeck+EShuffle',
#     'LibraryId': 2}]},
#  'LibraryId': 2,
#  'Values': [{'IdRef': 88, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 88, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 89, 'RecordTypeEnum': 'MemberReference'},
#   {'ClassInfo': {'ObjectId': -90,
#     'Name': 'MapRuleLibrary.YML.Events.CCardDeck+EShuffle',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_obj_value(output, 36)
# Out:
# {'ClassInfo': {'ObjectId': 36,
#   'Name': 'MapRuleLibrary.YML.Events.CCardDeck',
#   'MemberCount': 4,
#   'MemberNames': ['m_InitialCards',
#    'm_Cards',
#    'm_DiscardedCards',
#    'm_NeedsShuffle']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['SystemClass',
#    'SystemClass',
#    'SystemClass',
#    'Class'],
#   'AdditionalInfos': ['System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#    {'TypeName': 'MapRuleLibrary.YML.Events.CCardDeck+EShuffle',
#     'LibraryId': 2}]},
#  'LibraryId': 2,
#  'Values': [{'IdRef': 88, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 88, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 89, 'RecordTypeEnum': 'MemberReference'},
#   {'ClassInfo': {'ObjectId': -90,
#     'Name': 'MapRuleLibrary.YML.Events.CCardDeck+EShuffle',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_obj_value(output, 94)
# Out:
# {'ObjectId': 94,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 1334, 'RecordTypeEnum': 'MemberReference'}, 19, 3796],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 1334)
# Out:
# {'ArrayInfo': {'ObjectId': 1334, 'Length': 25},
#  'Values': [{'ObjectId': 10029,
#    'Value': 'PersonalQuest_Law_Bringer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10030,
#    'Value': 'PERSONALQUEST_Eternal_Wanderer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10031,
#    'Value': 'PERSONALQUEST_Piety_in_All_Things',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10032,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10033,
#    'Value': 'PERSONALQUEST_Implement_of_Light',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10034,
#    'Value': 'PERSONALQUEST_Finding_the_Cure',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10035,
#    'Value': 'PERSONALQUEST_Take_Back_the_Trees',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10036,
#    'Value': 'PERSONALQUEST_Elemental_Samples',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10037,
#    'Value': 'PERSONALQUEST_Trophy_Hunt',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10038,
#    'Value': 'PERSONALQUEST_Seeker_of_Xorn',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10039,
#    'Value': 'PERSONALQUEST_The_Thin_Places',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10040,
#    'Value': 'PERSONALQUEST_Foreverquest',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10041,
#    'Value': 'PERSONALQUEST_Zealot_of_the_Blood_God',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10042,
#    'Value': 'PERSONALQUEST_Greed_is_Good',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10043,
#    'Value': 'PERSONALQUEST_Goliath_Toppler',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10044,
#    'Value': 'PERSONALQUEST_Pounds_of_Flesh',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10045,
#    'Value': 'PERSONALQUEST_The_Perfect_Poison',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10046,
#    'Value': 'PERSONALQUEST_Battle_Legend',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10047,
#    'Value': 'PERSONALQUEST_A_Study_of_Anatomy',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 6, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_obj_value(output, 95)
# Out:
# {'ObjectId': 95,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 63, 'RecordTypeEnum': 'MemberReference'}, 0, 1],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 63)
# Out:
# {'ArrayInfo': {'ObjectId': 63, 'Length': 0},
#  'Values': [],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
output[0][78]["ClassInfo"]["MemberNames"]
# Out:
# ['CharacterName',
#  'CharacterID',
#  'm_CharacterGold',
#  'EXP',
#  'Level',
#  'CharacterPersistentEnhancements',
#  'OwnedAbilityCardIDs',
#  'HandAbilityCardIDs',
#  'Perks',
#  'PerkPoints',
#  'PerkChecks',
#  'TimesLevelReset',
#  'LastFreeLevelResetTicket',
#  'SkinId',
#  'PositiveConditions',
#  'NegativeConditions',
#  'PlayerRecords',
#  'NewEquippedItemsWithModifiers',
#  'PersonalQuest',
#  'PossiblePersonalQuests',
#  'PerksStartedWith',
#  'ExperiencePersonalGoal',
#  'EnhancementsBought',
#  'Donations',
#  'BattleGoalPerks',
#  'NextScenarioNegativeConditions',
#  'NextScenarioPositiveConditions',
#  'CurrentSmallItemOverride',
#  'CompletedSoloQuestData',
#  'EquippedItems',
#  'BoundItems']

# %%
output[0][78]["Values"][18]
# Out:
# {'IdRef': 1346, 'RecordTypeEnum': 'MemberReference'}

# %%
get_obj_value(output, 1346)
# Out:
# {'ClassInfo': {'ObjectId': 1346,
#   'Name': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'MemberCount': 9,
#   'MemberNames': ['ID',
#    'RewardGenerationRNGState',
#    'RolledRewards',
#    'PersonalQuestConditionState',
#    'IsConcealed',
#    'State',
#    'LastProgressShown',
#    'CurrentPersonalQuestStep',
#    'RewardsByStep']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['String',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Primitive',
#    'SystemClass'],
#   'AdditionalInfos': [None,
#    {'TypeName': 'ScenarioRuleLibrary.Extensions+RandomState', 'LibraryId': 3},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.Party.EPersonalQuestState', 'LibraryId': 2},
#    'Int32',
#    'Int32',
#    'System.Collections.Generic.List`1[[System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.RewardGroup, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]], mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]']},
#  'LibraryId': 2,
#  'Values': [{'ObjectId': 10049,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 10050, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 10051, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ClassInfo': {'ObjectId': -10052,
#     'Name': 'MapRuleLibrary.Party.EPersonalQuestState',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'},
#   5,
#   0,
#   {'IdRef': 10053, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
output[0][78]["Values"][19]
# Out:
# {'IdRef': 1347, 'RecordTypeEnum': 'MemberReference'}

# %%
get_obj_value(output, 1347)
# Out:
# {'ClassInfo': {'ObjectId': 1347,
#   'Name': 'System.Collections.Generic.List`1[[MapRuleLibrary.Party.CPersonalQuestState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#   'MemberCount': 3,
#   'MemberNames': ['_items', '_size', '_version']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['Class', 'Primitive', 'Primitive'],
#   'AdditionalInfos': [{'TypeName': 'MapRuleLibrary.Party.CPersonalQuestState[]',
#     'LibraryId': 2},
#    'Int32',
#    'Int32']},
#  'Values': [{'IdRef': 10054, 'RecordTypeEnum': 'MemberReference'}, 2, 0],
#  'RecordTypeEnum': 'SystemClassWithMembersAndTypes'}

# %%
get_obj_value(output, 10054)
# Out:
# {'ObjectId': 10054,
#  'BinaryArrayTypeEnum': 'Single',
#  'rank': 1,
#  'Lengths': [2],
#  'LowerBounds': [],
#  'TypeEnum': 'Class',
#  'AdditionalTypeInfo': {'TypeName': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'LibraryId': 2},
#  'Values': [{'IdRef': 26965, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1346, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'BinaryArray'}

# %%
get_obj_value(output, 26965)
# Out:
# {'ObjectId': 26965,
#  'MetadataId': 1346,
#  'Values': [{'ObjectId': 32710,
#    'Value': 'PERSONALQUEST_Greed_is_Good',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 32711, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 32712, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ObjectId': -32713,
#    'MetadataId': -10052,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'},
#   0,
#   0,
#   {'IdRef': 32714, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
output[0][1300]
# Out:
# {'ArrayInfo': {'ObjectId': 1334, 'Length': 25},
#  'Values': [{'ObjectId': 10019,
#    'Value': 'PERSONALQUEST_A_Study_of_Anatomy',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10020,
#    'Value': 'PERSONALQUEST_The_Perfect_Poison',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10021,
#    'Value': 'PERSONALQUEST_The_Thin_Places',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10022,
#    'Value': 'PERSONALQUEST_Foreverquest',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10023,
#    'Value': 'PERSONALQUEST_Take_Back_the_Trees',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10024,
#    'Value': 'PERSONALQUEST_Goliath_Toppler',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10025,
#    'Value': 'PERSONALQUEST_Piety_in_All_Things',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10026,
#    'Value': 'PERSONALQUEST_Battle_Legend',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10027,
#    'Value': 'PERSONALQUEST_Implement_of_Light',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10028,
#    'Value': 'PERSONALQUEST_Elemental_Samples',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10029,
#    'Value': 'PERSONALQUEST_Pounds_of_Flesh',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10030,
#    'Value': 'PERSONALQUEST_Finding_the_Cure',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10031,
#    'Value': 'PERSONALQUEST_Eternal_Wanderer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10032,
#    'Value': 'PERSONALQUEST_Zealot_of_the_Blood_God',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10033,
#    'Value': 'PERSONALQUEST_Seeker_of_Xorn',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10034,
#    'Value': 'PersonalQuest_Law_Bringer',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10035,
#    'Value': 'PERSONALQUEST_Trophy_Hunt',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10036,
#    'Value': 'PERSONALQUEST_Greed_is_Good',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10037,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 6, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_obj_value(output, 1346)
# Out:
# {'ClassInfo': {'ObjectId': 1346,
#   'Name': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'MemberCount': 9,
#   'MemberNames': ['ID',
#    'RewardGenerationRNGState',
#    'RolledRewards',
#    'PersonalQuestConditionState',
#    'IsConcealed',
#    'State',
#    'LastProgressShown',
#    'CurrentPersonalQuestStep',
#    'RewardsByStep']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['String',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Primitive',
#    'SystemClass'],
#   'AdditionalInfos': [None,
#    {'TypeName': 'ScenarioRuleLibrary.Extensions+RandomState', 'LibraryId': 3},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.Party.EPersonalQuestState', 'LibraryId': 2},
#    'Int32',
#    'Int32',
#    'System.Collections.Generic.List`1[[System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.RewardGroup, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]], mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]']},
#  'LibraryId': 2,
#  'Values': [{'ObjectId': 10049,
#    'Value': 'PERSONALQUEST_Merchant_Class',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 10050, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 10051, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ClassInfo': {'ObjectId': -10052,
#     'Name': 'MapRuleLibrary.Party.EPersonalQuestState',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithMembersAndTypes'},
#   5,
#   0,
#   {'IdRef': 10053, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_obj_value(output, 10051)
# Out:
# {'ClassInfo': {'ObjectId': 10051,
#   'Name': 'MapRuleLibrary.MapState.CUnlockConditionState',
#   'MemberCount': 11,
#   'MemberNames': ['IsInitialised',
#    'UnlockConditionTargetStates',
#    'FailConditionTargetStates',
#    'PreviousProgress',
#    'TotalConditions',
#    'ConditionsMet',
#    'Ordered',
#    'SingleScenario',
#    'Failed',
#    'OverrideCharacterID',
#    'OverrideCharacterName']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive',
#    'SystemClass',
#    'SystemClass',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'String',
#    'String'],
#   'AdditionalInfos': ['Boolean',
#    'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CUnlockConditionState+CUnlockConditionTargetState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#    'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CUnlockConditionState+CUnlockConditionTargetState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#    'Int32',
#    'Int32',
#    'Int32',
#    'Boolean',
#    'Boolean',
#    'Boolean',
#    None,
#    None]},
#  'LibraryId': 2,
#  'Values': [False,
#   {'IdRef': 26960, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 26961, 'RecordTypeEnum': 'MemberReference'},
#   6,
#   0,
#   0,
#   False,
#   False,
#   False,
#   {'IdRef': 1337, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1336, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_obj_value(output, 26959)
# Out:
# {'ArrayInfo': {'ObjectId': 26959, 'Length': 402},
#  'PrimitiveTypeEnum': 'Byte',
#  'Values': [0,
#   1,
#   0,
#   0,
#   0,
#   255,
#   255,
#   255,
#   255,
#   1,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   12,
#   2,
#   0,
#   0,
#   0,
#   68,
#   83,
#   104,
#   97,
#   114,
#   101,
#   100,
#   76,
#   105,
#   98,
#   114,
#   97,
#   114,
#   121,
#   44,
#   32,
#   86,
#   101,
#   114,
#   115,
#   105,
#   111,
#   110,
#   61,
#   48,
#   46,
#   48,
#   46,
#   48,
#   46,
#   48,
#   44,
#   32,
#   67,
#   117,
#   108,
#   116,
#   117,
#   114,
#   101,
#   61,
#   110,
#   101,
#   117,
#   116,
#   114,
#   97,
#   108,
#   44,
#   32,
#   80,
#   117,
#   98,
#   108,
#   105,
#   99,
#   75,
#   101,
#   121,
#   84,
#   111,
#   107,
#   101,
#   110,
#   61,
#   110,
#   117,
#   108,
#   108,
#   5,
#   1,
#   0,
#   0,
#   0,
#   20,
#   83,
#   104,
#   97,
#   114,
#   101,
#   100,
#   76,
#   105,
#   98,
#   114,
#   97,
#   114,
#   121,
#   46,
#   82,
#   97,
#   110,
#   100,
#   111,
#   109,
#   3,
#   0,
#   0,
#   0,
#   5,
#   105,
#   110,
#   101,
#   120,
#   116,
#   6,
#   105,
#   110,
#   101,
#   120,
#   116,
#   112,
#   9,
#   83,
#   101,
#   101,
#   100,
#   65,
#   114,
#   114,
#   97,
#   121,
#   0,
#   0,
#   7,
#   8,
#   8,
#   8,
#   2,
#   0,
#   0,
#   0,
#   27,
#   0,
#   0,
#   0,
#   48,
#   0,
#   0,
#   0,
#   9,
#   3,
#   0,
#   0,
#   0,
#   15,
#   3,
#   0,
#   0,
#   0,
#   56,
#   0,
#   0,
#   0,
#   8,
#   0,
#   0,
#   0,
#   0,
#   181,
#   105,
#   62,
#   50,
#   241,
#   44,
#   141,
#   87,
#   225,
#   1,
#   233,
#   38,
#   122,
#   117,
#   146,
#   89,
#   150,
#   135,
#   113,
#   120,
#   128,
#   78,
#   131,
#   26,
#   52,
#   23,
#   98,
#   112,
#   60,
#   45,
#   170,
#   111,
#   190,
#   102,
#   61,
#   11,
#   40,
#   94,
#   30,
#   31,
#   83,
#   8,
#   209,
#   115,
#   162,
#   111,
#   146,
#   65,
#   49,
#   132,
#   109,
#   118,
#   164,
#   200,
#   210,
#   51,
#   239,
#   250,
#   186,
#   75,
#   190,
#   57,
#   25,
#   82,
#   14,
#   171,
#   33,
#   98,
#   147,
#   116,
#   126,
#   100,
#   217,
#   32,
#   21,
#   65,
#   35,
#   170,
#   45,
#   79,
#   207,
#   220,
#   109,
#   121,
#   110,
#   113,
#   71,
#   14,
#   168,
#   136,
#   197,
#   66,
#   64,
#   160,
#   143,
#   61,
#   112,
#   108,
#   114,
#   104,
#   42,
#   187,
#   47,
#   73,
#   184,
#   201,
#   11,
#   111,
#   51,
#   140,
#   235,
#   25,
#   133,
#   1,
#   249,
#   88,
#   230,
#   183,
#   36,
#   109,
#   205,
#   128,
#   245,
#   16,
#   2,
#   114,
#   169,
#   108,
#   38,
#   69,
#   122,
#   112,
#   251,
#   251,
#   16,
#   93,
#   161,
#   99,
#   174,
#   36,
#   198,
#   44,
#   251,
#   16,
#   238,
#   85,
#   212,
#   116,
#   242,
#   157,
#   127,
#   20,
#   105,
#   246,
#   151,
#   116,
#   173,
#   230,
#   87,
#   20,
#   169,
#   115,
#   166,
#   54,
#   234,
#   92,
#   113,
#   99,
#   250,
#   100,
#   242,
#   72,
#   53,
#   132,
#   44,
#   107,
#   54,
#   49,
#   179,
#   102,
#   133,
#   226,
#   30,
#   38,
#   234,
#   252,
#   124,
#   95,
#   181,
#   86,
#   4,
#   32,
#   165,
#   98,
#   80,
#   62,
#   161,
#   60,
#   171,
#   19,
#   54,
#   214,
#   240,
#   114,
#   190,
#   125,
#   253,
#   127,
#   200,
#   203,
#   28,
#   71,
#   178,
#   89,
#   43,
#   33,
#   129,
#   77,
#   161,
#   19,
#   11],
#  'RecordTypeEnum': 'ArraySinglePrimitive'}

# %%
get_obj_value(output, 86)
# Out:
# {'ArrayInfo': {'ObjectId': 86, 'Length': 16},
#  'Values': [{'ObjectId': 128,
#    'Value': 'TT_Campaign_Chest_09',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 129,
#    'Value': 'TT_Campaign_Chest_10',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 130,
#    'Value': 'TT_Campaign_Chest_17',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 131,
#    'Value': 'TT_Campaign_Chest_21',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 132,
#    'Value': 'TT_Campaign_Chest_38',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 133,
#    'Value': 'TT_Campaign_Chest_39',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 134,
#    'Value': 'TT_Campaign_Chest_41',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 135,
#    'Value': 'TT_Campaign_Chest_46',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 136,
#    'Value': 'TT_Campaign_Chest_50',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 137,
#    'Value': 'TT_Campaign_Chest_67',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 138,
#    'Value': 'TT_Campaign_Chest_69',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 5, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_obj_value(output, 27127)
# Out:
# {'ArrayInfo': {'ObjectId': 27127, 'Length': 4},
#  'Values': [{'IdRef': 10107, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 32916, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1353, 'RecordTypeEnum': 'MemberReference'},
#   {'RecordTypeEnum': 'ObjectNull'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_obj_value(output, 10107)
# Out:
# {'ObjectId': 1461,
#  'MetadataId': 97,
#  'Values': [{'ObjectId': 10107,
#    'Value': 'Scoundrel',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 1444, 'RecordTypeEnum': 'MemberReference'},
#   301,
#   480,
#   6,
#   {'IdRef': 10109, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10110, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10111, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10112, 'RecordTypeEnum': 'MemberReference'},
#   13,
#   0,
#   0,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'IdRef': 10113, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10114, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10115, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10116, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10117, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10118, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   4,
#   0,
#   120,
#   24,
#   {'IdRef': 10119, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10120, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   {'IdRef': 10121, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10122, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10123, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_obj_value(output, 32916)
# Out:
# {'ArrayInfo': {'ObjectId': 27097, 'Length': 4},
#  'Values': [{'IdRef': 10107, 'RecordTypeEnum': 'MemberReference'},
#   {'ObjectId': 32916,
#    'Value': 'Spellweaver',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 2, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_obj_value(output, 1353)
# Out:
# {'ObjectId': 98,
#  'MetadataId': 97,
#  'Values': [{'ObjectId': 1353,
#    'Value': 'Emesh',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 1354,
#    'Value': 'CragheartID',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   42,
#   174,
#   4,
#   {'IdRef': 1355, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1356, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1357, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1358, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   1,
#   0,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'IdRef': 1359, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1360, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1361, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1362, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1363, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1364, 'RecordTypeEnum': 'MemberReference'},
#   2,
#   0,
#   0,
#   0,
#   1,
#   {'IdRef': 1365, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1366, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   {'IdRef': 1367, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1368, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 1369, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_key_value(output, "ObjectId", 11033)
# Out:
# [[0, 7711, 'ObjectId', 11033]]

# %%
output[0][7711]
# Out:
# {'ObjectId': 11033,
#  'MetadataId': 3620,
#  'Values': [False,
#   {'IdRef': 29769, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 29770, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   0,
#   0,
#   False,
#   False,
#   False,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_key_value(output, "ObjectId", 3620)
# Out:
# [[0, 2981, 'ClassInfo', 'ObjectId', 3620]]

# %%
output[0][2981]
# Out:
# {'ClassInfo': {'ObjectId': 3620,
#   'Name': 'MapRuleLibrary.MapState.CUnlockConditionState',
#   'MemberCount': 11,
#   'MemberNames': ['IsInitialised',
#    'UnlockConditionTargetStates',
#    'FailConditionTargetStates',
#    'PreviousProgress',
#    'TotalConditions',
#    'ConditionsMet',
#    'Ordered',
#    'SingleScenario',
#    'Failed',
#    'OverrideCharacterID',
#    'OverrideCharacterName']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive',
#    'SystemClass',
#    'SystemClass',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Primitive',
#    'Object',
#    'Object'],
#   'AdditionalInfos': ['Boolean',
#    'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CUnlockConditionState+CUnlockConditionTargetState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#    'System.Collections.Generic.List`1[[MapRuleLibrary.MapState.CUnlockConditionState+CUnlockConditionTargetState, MapRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]]',
#    'Int32',
#    'Int32',
#    'Int32',
#    'Boolean',
#    'Boolean',
#    'Boolean',
#    None,
#    None]},
#  'LibraryId': 2,
#  'Values': [False,
#   {'IdRef': 20592, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 20593, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   1,
#   0,
#   False,
#   False,
#   False,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'}],
#  'RecordTypeEnum': 'ClassWithMembersAndTypes'}

# %%
get_paths_to_value(output, "CompleteCharacterNames")
# Out:
# [[0, 1361, 'ClassInfo', 'MemberNames', 9, 'CompleteCharacterNames']]

# %%
output[0][1361]["Values"][9]
# Out:
# {'IdRef': 10166, 'RecordTypeEnum': 'MemberReference'}

# %%
get_paths_to_key_value(output, "ObjectId", 10166)
# Out:
# [[0, 7043, 'ObjectId', 10166]]

# %%
output[0][7043]
# Out:
# {'ObjectId': 10166,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 27097, 'RecordTypeEnum': 'MemberReference'}, 2, 2],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_key_value(output, "ObjectId", 27097)
# Out:
# [[0, 13387, 'ArrayInfo', 'ObjectId', 27097]]

# %%
output[0][13387]
# Out:
# {'ArrayInfo': {'ObjectId': 27097, 'Length': 4},
#  'Values': [{'IdRef': 10107, 'RecordTypeEnum': 'MemberReference'},
#   {'ObjectId': 32916,
#    'Value': 'Spellweaver',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'NullCount': 2, 'RecordTypeEnum': 'ObjectNullMultiple256'}],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
get_paths_to_key_value(output, "ObjectId", 10107)
# Out:
# [[0, 1358, 'Values', 0, 'ObjectId', 10107]]

# %%
output[0][1358]
# Out:
# {'ObjectId': 1461,
#  'MetadataId': 97,
#  'Values': [{'ObjectId': 10107,
#    'Value': 'Scoundrel',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 1444, 'RecordTypeEnum': 'MemberReference'},
#   301,
#   480,
#   6,
#   {'IdRef': 10109, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10110, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10111, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10112, 'RecordTypeEnum': 'MemberReference'},
#   13,
#   0,
#   0,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'IdRef': 10113, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10114, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10115, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10116, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10117, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10118, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   4,
#   0,
#   120,
#   24,
#   {'IdRef': 10119, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10120, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   {'IdRef': 10121, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10122, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10123, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %% [markdown]
# Get the object reference for it

# %%
output[0][5]["Values"][6]
# Out:
# {'IdRef': 38, 'RecordTypeEnum': 'MemberReference'}

# %% [markdown]
# Find that object

# %%
get_paths_to_key_value(output, "ObjectId", 38)
# Out:
# [[0, 32, 'ObjectId', 38]]

# %% [markdown]
# Get its child object references

# %%
output[0][32]
# Out:
# {'ObjectId': 38,
#  'MetadataId': 36,
#  'Values': [{'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 94, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 95, 'RecordTypeEnum': 'MemberReference'},
#   {'ObjectId': -96,
#    'MetadataId': -90,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %% [markdown]
# Find the first object reference

# %%
get_paths_to_key_value(output, "ObjectId", 94)
# Out:
# [[0, 76, 'ObjectId', 94]]

# %%
output[0][76]
# Out:
# {'ObjectId': 94,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 1334, 'RecordTypeEnum': 'MemberReference'}, 19, 3796],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_key_value(output, "ObjectId", 1334)
# Out:
# [[0, 1300, 'ArrayInfo', 'ObjectId', 1334]]

# %%
obj_info = get_paths_to_key_value(output, "ObjectId", 10134)
show_metadata(output[obj_info[0]][obj_info[1]], output)
# Out:
# [[0, 7015, 'ObjectId', 10134]]

# %%
pprint.pprint(show_metadata(output[0][7015], output), sort_dicts=False)
# Out:
# {'ID': {'ObjectId': 27035,
#         'Value': 'PERSONALQUEST_Vengeance',
#         'RecordTypeEnum': 'BinaryObjectString'},
#  'RewardGenerationRNGState': {'IdRef': 27036,
#                               'RecordTypeEnum': 'MemberReference'},
#  'RolledRewards': True,
#  'PersonalQuestConditionState': {'IdRef': 27037,
#                                  'RecordTypeEnum': 'MemberReference'},
#  'IsConcealed': False,
#  'State': {'ObjectId': -27038,
#            'MetadataId': -10052,
#            'Values': [0],
#            'RecordTypeEnum': 'ClassWithId'},
#  'LastProgressShown': 0,
#  'CurrentPersonalQuestStep': 0,
#  'RewardsByStep': {'IdRef': 27039, 'RecordTypeEnum': 'MemberReference'}}

# %%
a = {"a": 1, "b": 2}
for k, v in a.items():
    print(k, v)
# Out:
# a 1
# b 2

# %%
output[0][1359]
# Out:
# {'ObjectId': 1462,
#  'MetadataId': 97,
#  'Values': [{'ObjectId': 10124,
#    'Value': 'Dummy Spellweaver',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10125,
#    'Value': 'SpellweaverID',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   1072,
#   335,
#   3,
#   {'IdRef': 10126, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10127, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10128, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10129, 'RecordTypeEnum': 'MemberReference'},
#   5,
#   0,
#   0,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'IdRef': 10130, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10131, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10132, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10133, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10134, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10135, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   0,
#   0,
#   60,
#   0,
#   {'IdRef': 10136, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10137, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   {'IdRef': 10138, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10139, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10140, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
import pprint

def replace_idref(v, data, depth=2, current_idrefs=None):
    if isinstance(v, dict) and "IdRef" in v:
        if current_idrefs is None:
            obj_info = get_paths_to_key_value(data, "ObjectId", v["IdRef"])[0]
            current_idrefs = [v["IdRef"]]
            return show_metadata(data[obj_info[0]][obj_info[1]], data, depth=depth-1, current_idrefs=current_idrefs)
        else:
            if v["IdRef"] in current_idrefs:
                return None
            current_idrefs.append(v["IdRef"])
            obj_info = get_paths_to_key_value(data, "ObjectId", v["IdRef"])[0]
            return show_metadata(data[obj_info[0]][obj_info[1]], data, depth=depth-1, current_idrefs=current_idrefs)
    else:
        return None

def fill_ref(d, data, depth=2, current_idrefs=None):
    if depth <= 0:
        return d
    if isinstance(d, dict):
        for k, v in d.items():
            new_v = replace_idref(v, data, depth=depth, current_idrefs=current_idrefs)
            if new_v is not None:
                d[k] = new_v
            elif isinstance(v, list):
                for i, e in enumerate(v):
                    new_v = replace_idref(v, data, depth=depth, current_idrefs=current_idrefs)
                    if new_v is not None:
                        d[k][i] = new_v
    elif isinstance(d, list):
        for v in d:
            new_v = replace_idref(v, data, depth=depth, current_idrefs=current_idrefs)
            if new_v is not None:
                d[v] = new_v
    return d

def show_metadata(obj, data, depth=3, current_idrefs=None):
    if "MetadataId" in obj:
        classinfo = get_paths_to_key_value(output, "ObjectId", obj["MetadataId"])[0]
        membernames = output[classinfo[0]][classinfo[1]]["ClassInfo"]["MemberNames"]
        d = dict(list(zip(membernames, obj["Values"])))
    elif "_items" in obj:
        d = obj["_items"]["Values"]
    else:
        d = obj
    return fill_ref(d, data, depth=depth, current_idrefs=current_idrefs)
    
pprint.pprint(show_metadata(output[0][32], output), sort_dicts=False)
# Out:
# {'m_InitialCards': {'_items': {'ArrayInfo': {'ObjectId': 1334, 'Length': 25},
#                                'Values': [{'ObjectId': 10029,
#                                            'Value': 'PersonalQuest_Law_Bringer',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10030,
#                                            'Value': 'PERSONALQUEST_Eternal_Wanderer',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10031,
#                                            'Value': 'PERSONALQUEST_Piety_in_All_Things',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10032,
#                                            'Value': 'PERSONALQUEST_Merchant_Class',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10033,
#                                            'Value': 'PERSONALQUEST_Implement_of_Light',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10034,
#                                            'Value': 'PERSONALQUEST_Finding_the_Cure',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10035,
#                                            'Value': 'PERSONALQUEST_Take_Back_the_Trees',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10036,
#                                            'Value': 'PERSONALQUEST_Elemental_Samples',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10037,
#                                            'Value': 'PERSONALQUEST_Trophy_Hunt',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10038,
#                                            'Value': 'PERSONALQUEST_Seeker_of_Xorn',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10039,
#                                            'Value': 'PERSONALQUEST_The_Thin_Places',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10040,
#                                            'Value': 'PERSONALQUEST_Foreverquest',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10041,
#                                            'Value': 'PERSONALQUEST_Zealot_of_the_Blood_God',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10042,
#                                            'Value': 'PERSONALQUEST_Greed_is_Good',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10043,
#                                            'Value': 'PERSONALQUEST_Goliath_Toppler',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10044,
#                                            'Value': 'PERSONALQUEST_Pounds_of_Flesh',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10045,
#                                            'Value': 'PERSONALQUEST_The_Perfect_Poison',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10046,
#                                            'Value': 'PERSONALQUEST_Battle_Legend',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'ObjectId': 10047,
#                                            'Value': 'PERSONALQUEST_A_Study_of_Anatomy',
#                                            'RecordTypeEnum': 'BinaryObjectString'},
#                                           {'NullCount': 6,
#                                            'RecordTypeEnum': 'ObjectNullMultiple256'}],
#                                'RecordTypeEnum': 'ArraySingleString'},
#                     '_size': 19,
#                     '_version': 3842},
#  'm_Cards': {'_items': {'ArrayInfo': {'ObjectId': 1334, 'Length': 25},
#                         'Values': [{'ObjectId': 10029,
#                                     'Value': 'PersonalQuest_Law_Bringer',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10030,
#                                     'Value': 'PERSONALQUEST_Eternal_Wanderer',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10031,
#                                     'Value': 'PERSONALQUEST_Piety_in_All_Things',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10032,
#                                     'Value': 'PERSONALQUEST_Merchant_Class',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10033,
#                                     'Value': 'PERSONALQUEST_Implement_of_Light',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10034,
#                                     'Value': 'PERSONALQUEST_Finding_the_Cure',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10035,
#                                     'Value': 'PERSONALQUEST_Take_Back_the_Trees',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10036,
#                                     'Value': 'PERSONALQUEST_Elemental_Samples',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10037,
#                                     'Value': 'PERSONALQUEST_Trophy_Hunt',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10038,
#                                     'Value': 'PERSONALQUEST_Seeker_of_Xorn',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10039,
#                                     'Value': 'PERSONALQUEST_The_Thin_Places',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10040,
#                                     'Value': 'PERSONALQUEST_Foreverquest',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10041,
#                                     'Value': 'PERSONALQUEST_Zealot_of_the_Blood_God',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10042,
#                                     'Value': 'PERSONALQUEST_Greed_is_Good',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10043,
#                                     'Value': 'PERSONALQUEST_Goliath_Toppler',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10044,
#                                     'Value': 'PERSONALQUEST_Pounds_of_Flesh',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10045,
#                                     'Value': 'PERSONALQUEST_The_Perfect_Poison',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10046,
#                                     'Value': 'PERSONALQUEST_Battle_Legend',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'ObjectId': 10047,
#                                     'Value': 'PERSONALQUEST_A_Study_of_Anatomy',
#                                     'RecordTypeEnum': 'BinaryObjectString'},
#                                    {'NullCount': 6,
#                                     'RecordTypeEnum': 'ObjectNullMultiple256'}],
#                         'RecordTypeEnum': 'ArraySingleString'},
#              '_size': 19,
#              '_version': 3842},
#  'm_DiscardedCards': {'_items': {'ArrayInfo': {'ObjectId': 63, 'Length': 0},
#                                  'Values': [],
#                                  'RecordTypeEnum': 'ArraySingleString'},
#                       '_size': 0,
#                       '_version': 1},
#  'm_NeedsShuffle': {'ObjectId': -96,
#                     'MetadataId': -90,
#                     'Values': [0],
#                     'RecordTypeEnum': 'ClassWithId'}}

# %%
import struct
struct.pack("<I", 1334)
# Out:
# b'6\x05\x00\x00'

# %% [markdown]
# Find the second object reference

# %%
get_paths_to_key_value(output, "ObjectId", 95)
# Out:
# [[0, 77, 'ObjectId', 95]]

# %%
output[0][77]
# Out:
# {'ObjectId': 95,
#  'MetadataId': 19,
#  'Values': [{'IdRef': 63, 'RecordTypeEnum': 'MemberReference'}, 0, 1],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_key_value(output, "ObjectId", 63)
# Out:
# [[0, 53, 'ArrayInfo', 'ObjectId', 63]]

# %%
output[0][53]
# Out:
# {'ArrayInfo': {'ObjectId': 63, 'Length': 0},
#  'Values': [],
#  'RecordTypeEnum': 'ArraySingleString'}

# %%
output[0][76]
# Out:
# {'ObjectId': 94,
#  'MetadataId': 19,
#  'ClassInfo': {'ObjectId': 19,
#   'Name': 'System.Collections.Generic.List`1[[System.String, mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]',
#   'MemberCount': 3,
#   'MemberNames': ['_items', '_size', '_version']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['StringArray',
#    'Primitive',
#    'Primitive'],
#   'AdditionalInfos': [None, 'Int32', 'Int32']},
#  'RecordTypeEnum': 'ClassWithId',
#  'Values': [{'IdRef': 1334, 'RecordTypeEnum': 'MemberReference'}, 19, 3796]}

# %%
get_paths_to_value(output, "PERSONALQUEST_Vengeance")
# Out:
# [[0, 7015, 'Values', 0, 'Value', 'PERSONALQUEST_Vengeance']]

# %%
output[0][7015]
# Out:
# {'ObjectId': 10134,
#  'MetadataId': 1346,
#  'Values': [{'ObjectId': 27035,
#    'Value': 'PERSONALQUEST_Vengeance',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 27036, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 27037, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ObjectId': -27038,
#    'MetadataId': -10052,
#    'Values': [0],
#    'RecordTypeEnum': 'ClassWithId'},
#   0,
#   0,
#   {'IdRef': 27039, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
get_paths_to_value(output, 10134)
# Out:
# [[0, 1359, 'Values', 18, 'IdRef', 10134],
#  [0, 7015, 'ObjectId', 10134],
#  [0, 13351, 'Values', 1, 'IdRef', 10134]]

# %%
output[0][78]["ClassInfo"]["MemberNames"]
# Out:
# ['CharacterName',
#  'CharacterID',
#  'm_CharacterGold',
#  'EXP',
#  'Level',
#  'CharacterPersistentEnhancements',
#  'OwnedAbilityCardIDs',
#  'HandAbilityCardIDs',
#  'Perks',
#  'PerkPoints',
#  'PerkChecks',
#  'TimesLevelReset',
#  'LastFreeLevelResetTicket',
#  'SkinId',
#  'PositiveConditions',
#  'NegativeConditions',
#  'PlayerRecords',
#  'NewEquippedItemsWithModifiers',
#  'PersonalQuest',
#  'PossiblePersonalQuests',
#  'PerksStartedWith',
#  'ExperiencePersonalGoal',
#  'EnhancementsBought',
#  'Donations',
#  'BattleGoalPerks',
#  'NextScenarioNegativeConditions',
#  'NextScenarioPositiveConditions',
#  'CurrentSmallItemOverride',
#  'CompletedSoloQuestData',
#  'EquippedItems',
#  'BoundItems']

# %%
get_paths_to_value(output, 97)
# Out:
# [[0, 33, 'Values', 0, 'IdRef', 97],
#  [0, 64, 'Values', 25, 97],
#  [0, 64, 'Values', 33, 97],
#  [0, 64, 'Values', 68, 97],
#  [0, 64, 'Values', 99, 97],
#  [0, 64, 'Values', 107, 97],
#  [0, 64, 'Values', 112, 97],
#  [0, 64, 'Values', 142, 97],
#  [0, 68, 'Values', 25, 97],
#  [0, 68, 'Values', 33, 97],
#  [0, 68, 'Values', 68, 97],
#  [0, 68, 'Values', 99, 97],
#  [0, 68, 'Values', 107, 97],
#  [0, 68, 'Values', 112, 97],
#  [0, 68, 'Values', 142, 97],
#  [0, 68, 'Values', 193, 97],
#  [0, 78, 'ClassInfo', 'ObjectId', 97],
#  [0, 79, 'MetadataId', 97],
#  [0, 91, 'Values', 4, 'IdRef', 97],
#  [0, 1358, 'MetadataId', 97],
#  [0, 1359, 'MetadataId', 97],
#  [0, 1360, 'MetadataId', 97],
#  [0, 1530, 'Values', 10, 97],
#  [0, 7771, 'Values', 25, 97],
#  [0, 7771, 'Values', 33, 97],
#  [0, 7771, 'Values', 68, 97],
#  [0, 7771, 'Values', 99, 97],
#  [0, 7771, 'Values', 107, 97],
#  [0, 7771, 'Values', 112, 97],
#  [0, 7771, 'Values', 142, 97],
#  [0, 7771, 'Values', 237, 97],
#  [0, 7771, 'Values', 348, 97],
#  [0, 7771, 'Values', 396, 97],
#  [0, 7777, 'Values', 25, 97],
#  [0, 7777, 'Values', 33, 97],
#  [0, 7777, 'Values', 68, 97],
#  [0, 7777, 'Values', 99, 97],
#  [0, 7777, 'Values', 107, 97],
#  [0, 7777, 'Values', 112, 97],
#  [0, 7777, 'Values', 142, 97],
#  [0, 7777, 'Values', 324, 97],
#  [0, 7799, 'Values', 25, 97],
#  [0, 7799, 'Values', 33, 97],
#  [0, 7799, 'Values', 68, 97],
#  [0, 7799, 'Values', 99, 97],
#  [0, 7799, 'Values', 107, 97],
#  [0, 7799, 'Values', 112, 97],
#  [0, 7799, 'Values', 142, 97],
#  [0, 7799, 'Values', 322, 97],
#  [0, 7813, 'Values', 25, 97],

#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'ObjectId': 10125,
#    'Value': 'SpellweaverID',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   1072,
#   335,
#   3,
#   {'IdRef': 10126, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10127, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10128, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10129, 'RecordTypeEnum': 'MemberReference'},
#   5,
#   0,
#   0,
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'RecordTypeEnum': 'ObjectNull'},
#   {'IdRef': 10130, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10131, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10132, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10133, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10134, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10135, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   0,
#   0,
#   60,
#   0,
#   {'IdRef': 10136, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10137, 'RecordTypeEnum': 'MemberReference'},
#   0,
#   {'IdRef': 10138, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10139, 'RecordTypeEnum': 'MemberReference'},
#   {'IdRef': 10140, 'RecordTypeEnum': 'MemberReference'}],
#  'RecordTypeEnum': 'ClassWithId'}

# %%
output[0][7015]
# Out:
# {'ObjectId': 10134,
#  'MetadataId': 1346,
#  'ClassInfo': {'ObjectId': 1346,
#   'Name': 'MapRuleLibrary.Party.CPersonalQuestState',
#   'MemberCount': 9,
#   'MemberNames': ['ID',
#    'RewardGenerationRNGState',
#    'RolledRewards',
#    'PersonalQuestConditionState',
#    'IsConcealed',
#    'State',
#    'LastProgressShown',
#    'CurrentPersonalQuestStep',
#    'RewardsByStep']},
#  'MemberTypeInfo': {'BinaryTypeEnums': ['String',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Class',
#    'Primitive',
#    'Primitive',
#    'SystemClass'],
#   'AdditionalInfos': [None,
#    {'TypeName': 'ScenarioRuleLibrary.Extensions+RandomState', 'LibraryId': 3},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.MapState.CUnlockConditionState',
#     'LibraryId': 2},
#    'Boolean',
#    {'TypeName': 'MapRuleLibrary.Party.EPersonalQuestState', 'LibraryId': 2},
#    'Int32',
#    'Int32',
#    'System.Collections.Generic.List`1[[System.Collections.Generic.List`1[[ScenarioRuleLibrary.YML.RewardGroup, ScenarioRuleLibrary, Version=0.0.0.0, Culture=neutral, PublicKeyToken=null]], mscorlib, Version=4.0.0.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]]']},
#  'LibraryId': 2,
#  'RecordTypeEnum': 'ClassWithId',
#  'Values': [{'ObjectId': 27035,
#    'Value': 'PERSONALQUEST_Vengeance',
#    'RecordTypeEnum': 'BinaryObjectString'},
#   {'IdRef': 27036, 'RecordTypeEnum': 'MemberReference'},
#   True,
#   {'IdRef': 27037, 'RecordTypeEnum': 'MemberReference'},
#   False,
#   {'ObjectId': -27038,
#    'MetadataId': -10052,
#    'ClassInfo': {'ObjectId': -10052,
#     'Name': 'MapRuleLibrary.Party.EPersonalQuestState',
#     'MemberCount': 1,
#     'MemberNames': ['value__']},
#    'MemberTypeInfo': {'BinaryTypeEnums': ['Primitive'],
#     'AdditionalInfos': ['Int32']},
#    'LibraryId': 2,
#    'RecordTypeEnum': 'ClassWithId',
#    'Values': [0]},
#   0,
#   0,
#   {'IdRef': 27039, 'RecordTypeEnum': 'MemberReference'}]}
